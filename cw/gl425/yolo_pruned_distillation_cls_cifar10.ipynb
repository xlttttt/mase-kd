# %% [markdown]
# # YOLO CIFAR10: Fine-Tuned Teacher → Pruned Student → Logits Distillation (Classification)

# %% [markdown]
# This notebook runs a YOLOv8-cls **classification** knowledge distillation flow on CIFAR10 with a **pruned student**:
# 1. Load a **CIFAR10-fine-tuned** YOLOv8x-cls teacher (10-class head).
# 2. Instantiate a YOLOv8m-cls student, build a MASE graph, and apply **L1-norm structured pruning** to the desired sparsity.
# 3. Evaluate the pruned-but-untrained student as a baseline.
# 4. Finetune the pruned student with CE loss only (no teacher) as a second baseline.
# 5. Distill teacher logits into a fresh pruned student using CIFAR10 mini-batches (images + labels).
# 6. Evaluate teacher, pruned (no training), finetuned-only, and distilled student on CIFAR10 validation set.

# %%
TEACHER_CHECKPOINT = "data/cifar10_yolov8x_cls/runs/yolov8x_cls_cifar10_finetune/weights/best.pt"
DEVICE = "cuda"
DATA_ROOT = "./data"

IMAGE_SIZE = 32
BATCH_SIZE = 128

KD_ALPHA = 0.6
KD_TEMPERATURE = 8.0
EPOCHS = 50
lr = 5e-4
WEIGHT_DECAY = 0.05
PRUNE_SPARSITY = 0.5  # fraction of weights/activations to prune (0.0 = no pruning)

seed = 42

STUDENT_FINETUNED_SAVE_PATH = "data/notebook_test/best_student_finetuned_pruned_cifar10.pt"
KD_SAVE_PATH = "data/notebook_test/best_student_kd_pruned_cifar10.pt"

# %% [markdown]
# ## Imports and setup

# %%
import copy
import random
import sys
from pathlib import Path

import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from ultralytics import YOLO

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "pyproject.toml").exists() and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Could not locate repository root containing src/")

repo_root = find_repo_root(Path.cwd().resolve())
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from chop import MaseGraph
import chop.passes as passes
from chop.models.yolo.yolov8 import MaseYoloClassificationModel, patch_yolo

from mase_kd.core.losses import DistillationLossConfig, hard_label_ce_loss, soft_logit_kl_loss
from mase_kd.vision.yolo_kd import YOLOLogitsDistiller

print(f"Repo root: {repo_root}")
print(f"Using src path: {src_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Repo root: /workspace/mase-kd
# Using src path: /workspace/mase-kd/src

# %%
if DEVICE == "cuda" and not torch.cuda.is_available():
    DEVICE = "cpu"

print(f"Using device: {DEVICE}")

torch.manual_seed(seed)
random.seed(seed)
# Out:
# Using device: cuda

# %% [markdown]
# ## CIFAR10 image dataset and dataloaders

# %%
# Ultralytics trains YOLO on CIFAR10 with mean=(0,0,0), std=(1,1,1)
# Standard CIFAR10 augmentation pipeline to reduce overfitting.
cifar_transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.1, scale=(0.02, 0.2)),
])
cifar_transform_eval = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = datasets.CIFAR10(root=DATA_ROOT, train=True, transform=cifar_transform_train, download=True)
val_dataset = datasets.CIFAR10(root=DATA_ROOT, train=False, transform=cifar_transform_eval, download=True)

# drop_last=True keeps batch size fixed for the FX-specialized pruned student graph.
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    drop_last=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
    drop_last=True,
)

# %% [markdown]
# ## Load CIFAR10-fine-tuned teacher (YOLOv8x-cls, 10 classes)

# %%
# Two-step loading is necessary for two reasons:
# 1. Ultralytics .pt files are pickled objects (not plain state dicts), so YOLO() is the
#    safe deserializer. ultra_teacher.model.yaml is the only clean way to read `nc` (and
#    other arch params) before we can instantiate MaseYoloClassificationModel(nc=nc).
# 2. Once YOLO() has reconstructed the live model, ultra_teacher.model.state_dict() gives
#    a standard PyTorch state dict that maps 1:1 to MaseYoloClassificationModel's weights.
#    We need MaseYoloClassificationModel (not ultra_teacher.model directly) so that the
#    teacher's forward returns a flat [batch, nc] tensor; the raw ultralytics
#    ClassificationModel returns a structured tuple in train mode, which would cause
#    _flatten_logits to concatenate it into [batch, 2*nc].

ultra_teacher = YOLO(TEACHER_CHECKPOINT)
nc = ultra_teacher.model.yaml.get("nc", 10)

teacher_cls_model = MaseYoloClassificationModel(cfg="yolov8x-cls.yaml", nc=nc)
teacher_cls_model = patch_yolo(teacher_cls_model)
teacher_cls_model.load_state_dict(ultra_teacher.model.state_dict())
teacher_cls_model = teacher_cls_model.to(DEVICE)
teacher_cls_model.eval()

print(f"Loaded CIFAR10-fine-tuned teacher: {TEACHER_CHECKPOINT}")
print(f"Teacher num_classes (nc): {nc}")
# Out:
# Overriding model.yaml nc=1000 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   1653770  ultralytics.nn.modules.head.Classify         [1280, 10]
# YOLOv8x-cls summary: 104 layers, 56,154,650 parameters, 56,154,650 gradients, 154.3 GFLOPs
# Loaded CIFAR10-fine-tuned teacher: data/cifar10_yolov8x_cls/runs/yolov8x_cls_cifar10_finetune/weights/best.pt
# Teacher num_classes (nc): 10

# %% [markdown]
# ## Build and prune student model (YOLOv8m-cls)

# %%
import os

# Ensure save directories exist before any checkpoint is written.
os.makedirs(os.path.dirname(STUDENT_FINETUNED_SAVE_PATH), exist_ok=True)
os.makedirs(os.path.dirname(KD_SAVE_PATH), exist_ok=True)

# Build a randomly-initialised YOLOv8m-cls student.
student_seed = MaseYoloClassificationModel(cfg="yolov8m-cls.yaml", nc=nc)
student_seed = patch_yolo(student_seed)

# Build MASE graph and run metadata analysis passes required by the pruning pass.
mg = MaseGraph(student_seed)
mg, _ = passes.init_metadata_analysis_pass(mg)

trace_input = torch.randn(BATCH_SIZE, 3, IMAGE_SIZE, IMAGE_SIZE)
placeholder_names = [n.name for n in mg.fx_graph.nodes if n.op == "placeholder"]
dummy_in = {name: trace_input for name in placeholder_names}

mg, _ = passes.add_common_metadata_analysis_pass(mg, pass_args={"dummy_in": dummy_in})

pruning_config = {
    "weight":     {"sparsity": PRUNE_SPARSITY, "method": "l1-norm", "scope": "local"},
    "activation": {"sparsity": PRUNE_SPARSITY, "method": "l1-norm", "scope": "local"},
}
mg, _ = passes.prune_transform_pass(mg, pass_args=pruning_config)

pruned_model = mg.model.to(DEVICE)
del mg, student_seed, trace_input, dummy_in

print(f"Student model (yolov8m-cls) pruned at {PRUNE_SPARSITY*100:.0f}% sparsity.")

# Snapshot the pruned (untrained) weights — used to reset the student for KD.
pruned_snapshot_state = copy.deepcopy(pruned_model.state_dict())

# Pruned-but-untrained baseline for comparison.
baseline_pruned_model = copy.deepcopy(pruned_model).to(DEVICE)
baseline_pruned_model.eval()

# student_cls_model starts from the pruned state; will be used for distillation.
student_cls_model = pruned_model
# Out:
# Overriding model.yaml nc=1000 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.conv.Conv             [384, 768, 3, 2]
#   8                  -1  2   7084032  ultralytics.nn.modules.block.C2f             [768, 768, 2, True]
#   9                  -1  1    998410  ultralytics.nn.modules.head.Classify         [768, 10]
# YOLOv8m-cls summary: 80 layers, 15,785,146 parameters, 15,785,146 gradients, 41.9 GFLOPs
# tensor([[[[ 1.0501]],
#
#          [[-0.1920]],
#
#          [[-0.2778]],
#
#          ...,
#
#          [[ 1.9353]],
#
#          [[ 0.3788]],
#
#          [[-0.2585]]],
#
#
#         [[[-0.2716]],
#
#          [[-0.0915]],
#
#          [[-0.1119]],
#
#          ...,
#
#          [[-0.2768]],
#
#          [[-0.2782]],
#
#          [[ 0.2242]]],
#
#
#         [[[-0.1149]],
#
#          [[-0.2146]],
#
#          [[-0.2248]],
#
#          ...,
#
#          [[ 0.0134]],
#
#          [[-0.0318]],
#
#          [[-0.1247]]],
#
#
#         ...,
#
#
#         [[[-0.2724]],
#
#          [[-0.2021]],
#
#          [[ 0.0028]],
#
#          ...,
#
#          [[ 0.6303]],
#
#          [[ 0.0542]],
#
#          [[-0.0973]]],
#
#
#         [[[-0.1862]],
#
#          [[ 0.0147]],
#
#          [[-0.2775]],
#
#          ...,
#
#          [[ 0.2858]],
#
#          [[-0.1975]],
#
#          [[ 1.1147]]],
#
#
#         [[[ 0.2417]],
#
#          [[-0.1268]],
#
#          [[ 2.1179]],
#
#          ...,
#
#          [[ 0.1343]],
#
#          [[ 0.4316]],
#
#          [[ 1.7110]]]], grad_fn=<MeanBackward1>)
# INFO     Pruning module: model_0_conv
# INFO     Pruning module: model_1_conv
# INFO     Pruning module: model_2_cv1_conv
# INFO     Pruning module: model_2_m_0_cv1_conv
# INFO     Pruning module: model_2_m_0_cv2_conv
# INFO     Pruning module: model_2_m_1_cv1_conv
# INFO     Pruning module: model_2_m_1_cv2_conv
# INFO     Pruning module: model_2_cv2_conv
# INFO     Pruning module: model_3_conv
# INFO     Pruning module: model_4_cv1_conv
# INFO     Pruning module: model_4_m_0_cv1_conv
# INFO     Pruning module: model_4_m_0_cv2_conv
# INFO     Pruning module: model_4_m_1_cv1_conv
# INFO     Pruning module: model_4_m_1_cv2_conv
# INFO     Pruning module: model_4_m_2_cv1_conv
# INFO     Pruning module: model_4_m_2_cv2_conv
# INFO     Pruning module: model_4_m_3_cv1_conv
# INFO     Pruning module: model_4_m_3_cv2_conv
# INFO     Pruning module: model_4_cv2_conv
# INFO     Pruning module: model_5_conv
# INFO     Pruning module: model_6_cv1_conv
# INFO     Pruning module: model_6_m_0_cv1_conv
# INFO     Pruning module: model_6_m_0_cv2_conv
# INFO     Pruning module: model_6_m_1_cv1_conv
# INFO     Pruning module: model_6_m_1_cv2_conv
# INFO     Pruning module: model_6_m_2_cv1_conv
# INFO     Pruning module: model_6_m_2_cv2_conv
# INFO     Pruning module: model_6_m_3_cv1_conv
# INFO     Pruning module: model_6_m_3_cv2_conv
# INFO     Pruning module: model_6_cv2_conv
# INFO     Pruning module: model_7_conv
# INFO     Pruning module: model_8_cv1_conv
# INFO     Pruning module: model_8_m_0_cv1_conv
# INFO     Pruning module: model_8_m_0_cv2_conv
# INFO     Pruning module: model_8_m_1_cv1_conv
# INFO     Pruning module: model_8_m_1_cv2_conv
# INFO     Pruning module: model_8_cv2_conv
# INFO     Pruning module: model_9_conv_conv
# INFO     Pruning module: model_9_linear
# Student model (yolov8m-cls) pruned at 50% sparsity.

# %% [markdown]
# ## Evaluate pruned student (no training)

# %%
import time

@torch.no_grad()
def evaluate_model_on_cifar10_val(model, loader, device):
    """Evaluate a model on the full validation loader. Returns top-1/top-5 accuracy, CE loss, and timing."""
    model.eval()
    batches = 0
    samples = 0
    total_forward_ms = 0.0
    correct_top1 = 0
    correct_top5 = 0
    total_ce_loss = 0.0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)
        if device == "cuda":
            torch.cuda.synchronize()
        t0 = time.perf_counter()
        model.train()  # train mode → Classify head returns raw logits, not softmax
        outputs = model(images)
        model.eval()
        if device == "cuda":
            torch.cuda.synchronize()
        t1 = time.perf_counter()

        outputs = YOLOLogitsDistiller._unwrap_classify_output(outputs)
        logits = YOLOLogitsDistiller._extract_logits_with_batch(outputs, images.shape[0])
        if logits is None or logits.numel() == 0:
            continue

        total_forward_ms += (t1 - t0) * 1000.0
        batches += 1
        samples += images.shape[0]

        max_label = int(labels.max().item())
        if logits.shape[1] > max_label:
            preds = logits.argmax(dim=1)
            correct_top1 += int((preds == labels).sum().item())
            k = min(5, logits.shape[1])
            top_k_indices = logits.topk(k, dim=1).indices
            correct_top5 += int(
                (top_k_indices == labels.unsqueeze(1)).any(dim=1).sum().item()
            )
            total_ce_loss += hard_label_ce_loss(logits, labels).item()

    return {
        "batches": batches,
        "samples": samples,
        "avg_forward_ms_per_batch": total_forward_ms / max(batches, 1),
        "top1_acc": correct_top1 / max(samples, 1),
        "top5_acc": correct_top5 / max(samples, 1),
        "avg_ce_loss": total_ce_loss / max(batches, 1),
    }

baseline_pruned_metrics = evaluate_model_on_cifar10_val(baseline_pruned_model, val_loader, DEVICE)
print(f"Student (pruned {PRUNE_SPARSITY*100:.0f}%, no training):")
print(
    f"  top1_acc={baseline_pruned_metrics['top1_acc']*100:.2f}% | "
    f"top5_acc={baseline_pruned_metrics['top5_acc']*100:.2f}% | "
    f"CE_loss={baseline_pruned_metrics['avg_ce_loss']:.4f} | "
    f"fwd_ms/batch={baseline_pruned_metrics['avg_forward_ms_per_batch']:.2f} | "
    f"samples={baseline_pruned_metrics['samples']}"
)
# Out:
# Student (pruned 50%, no training):
#   top1_acc=10.69% | top5_acc=49.80% | CE_loss=2.3750 | fwd_ms/batch=104.29 | samples=9984

# %% [markdown]
# ## Finetune and evaluate pruned student (No Distillation)

# %%
# Fine-tune a copy of the pruned student with CE loss only (no distillation).
student_finetuned_model = copy.deepcopy(baseline_pruned_model).to(DEVICE)
ft_optimizer = torch.optim.AdamW(student_finetuned_model.parameters(), lr=lr, weight_decay=WEIGHT_DECAY)

ft_loss_history = []
ft_top1_history = []
ft_top5_history = []
ft_val_top1_history = []  # per-epoch validation top-1
ft_val_top5_history = []  # per-epoch validation top-5
ft_val_loss_history = []  # per-epoch validation CE loss

best_ft_top1: float | None = None

for epoch in range(1, EPOCHS + 1):
    student_finetuned_model.train()
    total_loss = 0.0
    num_batches = len(train_loader)
    epoch_top1 = []

    for batch_idx, (images, labels) in enumerate(train_loader, start=1):
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)
        ft_optimizer.zero_grad(set_to_none=True)

        outputs = student_finetuned_model(images)
        logits = YOLOLogitsDistiller._extract_logits_with_batch(outputs, images.shape[0])
        loss = hard_label_ce_loss(logits, labels)
        loss.backward()
        ft_optimizer.step()
        total_loss += loss.item()

        with torch.no_grad():
            n_classes = logits.shape[1]
            preds_top1 = logits.argmax(dim=1)
            top1 = float((preds_top1 == labels).float().mean().item())
            k = min(5, n_classes)
            top_k_indices = logits.topk(k, dim=1).indices
            top5 = float((top_k_indices == labels.unsqueeze(1)).any(dim=1).float().mean().item())

        ft_loss_history.append(loss.item())
        ft_top1_history.append(top1)
        ft_top5_history.append(top5)
        epoch_top1.append(top1)

        if batch_idx == 1 or batch_idx % 100 == 0 or batch_idx == num_batches:
            print(
                f"  Epoch {epoch}/{EPOCHS} | Batch {batch_idx:04d}/{num_batches} | "
                f"loss={loss.item():.6f} | top1={top1*100:.2f}% | top5={top5*100:.2f}%"
            )
    print(f"Epoch {epoch} avg train loss: {total_loss / num_batches:.6f}")

    # Per-epoch validation
    val_metrics = evaluate_model_on_cifar10_val(student_finetuned_model, val_loader, DEVICE)
    ft_val_top1_history.append(val_metrics["top1_acc"])
    ft_val_top5_history.append(val_metrics["top5_acc"])
    ft_val_loss_history.append(val_metrics["avg_ce_loss"])
    print(
        f"  Val: top1_acc={val_metrics['top1_acc']*100:.2f}% | "
        f"top5_acc={val_metrics['top5_acc']*100:.2f}% | "
        f"CE_loss={val_metrics['avg_ce_loss']:.4f}"
    )

    # Save best model based on validation top-1 accuracy.
    if best_ft_top1 is None or val_metrics["top1_acc"] > best_ft_top1:
        best_ft_top1 = val_metrics["top1_acc"]
        torch.save(student_finetuned_model.state_dict(), STUDENT_FINETUNED_SAVE_PATH)
        print(f"  [checkpoint] New best val_top1={val_metrics['top1_acc']:.6f} — model saved to '{STUDENT_FINETUNED_SAVE_PATH}'")

# strict=False: pruning masks are non-persistent buffers excluded from state_dict but
# already present and unchanged on this model instance, so only weights need restoring.
student_finetuned_model.load_state_dict(
    torch.load(STUDENT_FINETUNED_SAVE_PATH, weights_only=True), strict=False
)
print(f"Loaded best finetuned weights from '{STUDENT_FINETUNED_SAVE_PATH}' for evaluation.")

student_finetuned_metrics = evaluate_model_on_cifar10_val(student_finetuned_model, val_loader, DEVICE)
print(f"\nStudent (pruned {PRUNE_SPARSITY*100:.0f}%, finetuned {EPOCHS} epochs, no KD):")
print(
    f"  top1_acc={student_finetuned_metrics['top1_acc']*100:.2f}% | "
    f"top5_acc={student_finetuned_metrics['top5_acc']*100:.2f}% | "
    f"CE_loss={student_finetuned_metrics['avg_ce_loss']:.4f} | "
    f"fwd_ms/batch={student_finetuned_metrics['avg_forward_ms_per_batch']:.2f} | "
    f"samples={student_finetuned_metrics['samples']}"
)
# Out:
#   Epoch 1/50 | Batch 0001/390 | loss=2.436533 | top1=10.16% | top5=44.53%
#   Epoch 1/50 | Batch 0100/390 | loss=2.089478 | top1=20.31% | top5=71.09%
#   Epoch 1/50 | Batch 0200/390 | loss=2.027992 | top1=21.88% | top5=80.47%
#   Epoch 1/50 | Batch 0300/390 | loss=1.900139 | top1=35.16% | top5=84.38%
#   Epoch 1/50 | Batch 0390/390 | loss=1.955711 | top1=27.34% | top5=82.81%
# Epoch 1 avg train loss: 2.060759
#   Val: top1_acc=28.17% | top5_acc=81.04% | CE_loss=1.9267
#   [checkpoint] New best val_top1=0.281651 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 2/50 | Batch 0001/390 | loss=2.002946 | top1=27.34% | top5=73.44%
#   Epoch 2/50 | Batch 0100/390 | loss=2.036953 | top1=27.34% | top5=82.03%
#   Epoch 2/50 | Batch 0200/390 | loss=1.869861 | top1=30.47% | top5=82.81%
#   Epoch 2/50 | Batch 0300/390 | loss=1.686795 | top1=39.06% | top5=87.50%
#   Epoch 2/50 | Batch 0390/390 | loss=1.826362 | top1=27.34% | top5=88.28%
# Epoch 2 avg train loss: 1.867282
#   Val: top1_acc=33.72% | top5_acc=85.04% | CE_loss=1.7941
#   [checkpoint] New best val_top1=0.337240 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 3/50 | Batch 0001/390 | loss=1.856170 | top1=31.25% | top5=82.03%
#   Epoch 3/50 | Batch 0100/390 | loss=1.764226 | top1=28.12% | top5=82.81%
#   Epoch 3/50 | Batch 0200/390 | loss=1.867930 | top1=31.25% | top5=79.69%
#   Epoch 3/50 | Batch 0300/390 | loss=1.828071 | top1=33.59% | top5=90.62%
#   Epoch 3/50 | Batch 0390/390 | loss=1.864583 | top1=32.81% | top5=84.38%
# Epoch 3 avg train loss: 1.769525
#   Val: top1_acc=37.85% | top5_acc=86.83% | CE_loss=1.7284
#   [checkpoint] New best val_top1=0.378506 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 4/50 | Batch 0001/390 | loss=1.747852 | top1=38.28% | top5=85.94%
#   Epoch 4/50 | Batch 0100/390 | loss=1.711707 | top1=39.84% | top5=89.84%
#   Epoch 4/50 | Batch 0200/390 | loss=1.744329 | top1=36.72% | top5=84.38%
#   Epoch 4/50 | Batch 0300/390 | loss=1.500782 | top1=47.66% | top5=90.62%
#   Epoch 4/50 | Batch 0390/390 | loss=1.733797 | top1=33.59% | top5=89.84%
# Epoch 4 avg train loss: 1.685632
#   Val: top1_acc=41.97% | top5_acc=88.30% | CE_loss=1.6162
#   [checkpoint] New best val_top1=0.419671 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 5/50 | Batch 0001/390 | loss=1.608472 | top1=40.62% | top5=91.41%
#   Epoch 5/50 | Batch 0100/390 | loss=1.648097 | top1=42.19% | top5=88.28%
#   Epoch 5/50 | Batch 0200/390 | loss=1.631960 | top1=41.41% | top5=85.94%
#   Epoch 5/50 | Batch 0300/390 | loss=1.562838 | top1=42.19% | top5=88.28%
#   Epoch 5/50 | Batch 0390/390 | loss=1.720227 | top1=36.72% | top5=84.38%
# Epoch 5 avg train loss: 1.609557
#   Val: top1_acc=44.40% | top5_acc=89.69% | CE_loss=1.5466
#   [checkpoint] New best val_top1=0.444010 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 6/50 | Batch 0001/390 | loss=1.636751 | top1=41.41% | top5=88.28%
#   Epoch 6/50 | Batch 0100/390 | loss=1.716172 | top1=41.41% | top5=88.28%
#   Epoch 6/50 | Batch 0200/390 | loss=1.795210 | top1=36.72% | top5=83.59%
#   Epoch 6/50 | Batch 0300/390 | loss=1.370072 | top1=53.12% | top5=91.41%
#   Epoch 6/50 | Batch 0390/390 | loss=1.612352 | top1=43.75% | top5=88.28%
# Epoch 6 avg train loss: 1.560667
#   Val: top1_acc=46.32% | top5_acc=90.62% | CE_loss=1.5005
#   [checkpoint] New best val_top1=0.463241 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 7/50 | Batch 0001/390 | loss=1.512466 | top1=46.88% | top5=86.72%
#   Epoch 7/50 | Batch 0100/390 | loss=1.584421 | top1=39.06% | top5=90.62%
#   Epoch 7/50 | Batch 0200/390 | loss=1.665933 | top1=38.28% | top5=89.84%
#   Epoch 7/50 | Batch 0300/390 | loss=1.502941 | top1=51.56% | top5=89.84%
#   Epoch 7/50 | Batch 0390/390 | loss=1.311707 | top1=55.47% | top5=93.75%
# Epoch 7 avg train loss: 1.490491
#   Val: top1_acc=48.77% | top5_acc=91.45% | CE_loss=1.4499
#   [checkpoint] New best val_top1=0.487680 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 8/50 | Batch 0001/390 | loss=1.697715 | top1=46.09% | top5=83.59%
#   Epoch 8/50 | Batch 0100/390 | loss=1.680526 | top1=43.75% | top5=86.72%
#   Epoch 8/50 | Batch 0200/390 | loss=1.599404 | top1=46.88% | top5=89.06%
#   Epoch 8/50 | Batch 0300/390 | loss=1.283210 | top1=59.38% | top5=95.31%
#   Epoch 8/50 | Batch 0390/390 | loss=1.487911 | top1=44.53% | top5=90.62%
# Epoch 8 avg train loss: 1.470218
#   Val: top1_acc=49.54% | top5_acc=92.29% | CE_loss=1.4051
#   [checkpoint] New best val_top1=0.495393 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 9/50 | Batch 0001/390 | loss=1.434530 | top1=50.78% | top5=88.28%
#   Epoch 9/50 | Batch 0100/390 | loss=1.491949 | top1=49.22% | top5=91.41%
#   Epoch 9/50 | Batch 0200/390 | loss=1.409750 | top1=47.66% | top5=92.19%
#   Epoch 9/50 | Batch 0300/390 | loss=1.469845 | top1=48.44% | top5=85.94%
#   Epoch 9/50 | Batch 0390/390 | loss=1.335143 | top1=52.34% | top5=92.97%
# Epoch 9 avg train loss: 1.443529
#   Val: top1_acc=50.03% | top5_acc=92.60% | CE_loss=1.3993
#   [checkpoint] New best val_top1=0.500300 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 10/50 | Batch 0001/390 | loss=1.335163 | top1=49.22% | top5=90.62%
#   Epoch 10/50 | Batch 0100/390 | loss=1.552318 | top1=46.88% | top5=92.97%
#   Epoch 10/50 | Batch 0200/390 | loss=1.420300 | top1=48.44% | top5=92.19%
#   Epoch 10/50 | Batch 0300/390 | loss=1.508990 | top1=49.22% | top5=92.19%
#   Epoch 10/50 | Batch 0390/390 | loss=1.409081 | top1=47.66% | top5=92.97%
# Epoch 10 avg train loss: 1.397525
#   Val: top1_acc=50.07% | top5_acc=92.62% | CE_loss=1.3957
#   [checkpoint] New best val_top1=0.500701 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 11/50 | Batch 0001/390 | loss=1.357593 | top1=53.91% | top5=92.97%
#   Epoch 11/50 | Batch 0100/390 | loss=1.542237 | top1=46.09% | top5=88.28%
#   Epoch 11/50 | Batch 0200/390 | loss=1.411708 | top1=46.09% | top5=92.97%
#   Epoch 11/50 | Batch 0300/390 | loss=1.297599 | top1=54.69% | top5=92.97%
#   Epoch 11/50 | Batch 0390/390 | loss=1.515642 | top1=48.44% | top5=92.97%
# Epoch 11 avg train loss: 1.394572
#   Val: top1_acc=52.50% | top5_acc=93.05% | CE_loss=1.3473
#   [checkpoint] New best val_top1=0.525040 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 12/50 | Batch 0001/390 | loss=1.345314 | top1=52.34% | top5=94.53%
#   Epoch 12/50 | Batch 0100/390 | loss=1.489500 | top1=44.53% | top5=89.84%
#   Epoch 12/50 | Batch 0200/390 | loss=1.346605 | top1=49.22% | top5=90.62%
#   Epoch 12/50 | Batch 0300/390 | loss=1.452313 | top1=50.78% | top5=96.09%
#   Epoch 12/50 | Batch 0390/390 | loss=1.371123 | top1=55.47% | top5=89.06%
# Epoch 12 avg train loss: 1.347716
#   Val: top1_acc=52.38% | top5_acc=93.14% | CE_loss=1.3327
#   Epoch 13/50 | Batch 0001/390 | loss=1.253761 | top1=54.69% | top5=96.09%
#   Epoch 13/50 | Batch 0100/390 | loss=1.369637 | top1=53.12% | top5=91.41%
#   Epoch 13/50 | Batch 0200/390 | loss=1.149541 | top1=56.25% | top5=96.88%
#   Epoch 13/50 | Batch 0300/390 | loss=1.436711 | top1=46.09% | top5=89.06%
#   Epoch 13/50 | Batch 0390/390 | loss=1.167188 | top1=62.50% | top5=91.41%
# Epoch 13 avg train loss: 1.325115
#   Val: top1_acc=54.24% | top5_acc=93.54% | CE_loss=1.2883
#   [checkpoint] New best val_top1=0.542368 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 14/50 | Batch 0001/390 | loss=1.269989 | top1=58.59% | top5=93.75%
#   Epoch 14/50 | Batch 0100/390 | loss=1.323296 | top1=52.34% | top5=92.97%
#   Epoch 14/50 | Batch 0200/390 | loss=1.353788 | top1=53.91% | top5=90.62%
#   Epoch 14/50 | Batch 0300/390 | loss=1.379084 | top1=49.22% | top5=91.41%
#   Epoch 14/50 | Batch 0390/390 | loss=1.464962 | top1=48.44% | top5=92.97%
# Epoch 14 avg train loss: 1.290833
#   Val: top1_acc=55.20% | top5_acc=94.02% | CE_loss=1.2661
#   [checkpoint] New best val_top1=0.551983 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 15/50 | Batch 0001/390 | loss=1.371228 | top1=57.03% | top5=92.97%
#   Epoch 15/50 | Batch 0100/390 | loss=1.383100 | top1=52.34% | top5=92.97%
#   Epoch 15/50 | Batch 0200/390 | loss=1.240783 | top1=57.81% | top5=92.97%
#   Epoch 15/50 | Batch 0300/390 | loss=1.108542 | top1=64.06% | top5=96.09%
#   Epoch 15/50 | Batch 0390/390 | loss=1.074380 | top1=57.03% | top5=95.31%
# Epoch 15 avg train loss: 1.256790
#   Val: top1_acc=56.04% | top5_acc=93.86% | CE_loss=1.2549
#   [checkpoint] New best val_top1=0.560397 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 16/50 | Batch 0001/390 | loss=1.302100 | top1=55.47% | top5=91.41%
#   Epoch 16/50 | Batch 0100/390 | loss=1.211651 | top1=50.78% | top5=94.53%
#   Epoch 16/50 | Batch 0200/390 | loss=1.299937 | top1=54.69% | top5=93.75%
#   Epoch 16/50 | Batch 0300/390 | loss=1.256369 | top1=57.81% | top5=93.75%
#   Epoch 16/50 | Batch 0390/390 | loss=1.217391 | top1=57.81% | top5=92.19%
# Epoch 16 avg train loss: 1.254535
#   Val: top1_acc=57.44% | top5_acc=94.31% | CE_loss=1.2051
#   [checkpoint] New best val_top1=0.574419 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 17/50 | Batch 0001/390 | loss=1.249300 | top1=55.47% | top5=95.31%
#   Epoch 17/50 | Batch 0100/390 | loss=1.278942 | top1=60.94% | top5=95.31%
#   Epoch 17/50 | Batch 0200/390 | loss=1.293991 | top1=58.59% | top5=91.41%
#   Epoch 17/50 | Batch 0300/390 | loss=1.192630 | top1=59.38% | top5=96.09%
#   Epoch 17/50 | Batch 0390/390 | loss=1.429847 | top1=45.31% | top5=90.62%
# Epoch 17 avg train loss: 1.229474
#   Val: top1_acc=53.70% | top5_acc=93.96% | CE_loss=1.3142
#   Epoch 18/50 | Batch 0001/390 | loss=1.471333 | top1=50.78% | top5=91.41%
#   Epoch 18/50 | Batch 0100/390 | loss=1.061561 | top1=62.50% | top5=96.88%
#   Epoch 18/50 | Batch 0200/390 | loss=1.224121 | top1=61.72% | top5=90.62%
#   Epoch 18/50 | Batch 0300/390 | loss=1.163875 | top1=54.69% | top5=96.09%
#   Epoch 18/50 | Batch 0390/390 | loss=1.225340 | top1=59.38% | top5=96.88%
# Epoch 18 avg train loss: 1.234838
#   Val: top1_acc=58.54% | top5_acc=94.73% | CE_loss=1.1840
#   [checkpoint] New best val_top1=0.585437 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 19/50 | Batch 0001/390 | loss=1.055170 | top1=63.28% | top5=96.88%
#   Epoch 19/50 | Batch 0100/390 | loss=1.333381 | top1=56.25% | top5=88.28%
#   Epoch 19/50 | Batch 0200/390 | loss=1.342056 | top1=55.47% | top5=90.62%
#   Epoch 19/50 | Batch 0300/390 | loss=1.391365 | top1=53.91% | top5=94.53%
#   Epoch 19/50 | Batch 0390/390 | loss=1.080137 | top1=62.50% | top5=94.53%
# Epoch 19 avg train loss: 1.231383
#   Val: top1_acc=58.54% | top5_acc=95.04% | CE_loss=1.1726
#   Epoch 20/50 | Batch 0001/390 | loss=1.195295 | top1=60.16% | top5=93.75%
#   Epoch 20/50 | Batch 0100/390 | loss=1.222741 | top1=57.81% | top5=92.97%
#   Epoch 20/50 | Batch 0200/390 | loss=1.248411 | top1=52.34% | top5=96.88%
#   Epoch 20/50 | Batch 0300/390 | loss=1.137252 | top1=59.38% | top5=93.75%
#   Epoch 20/50 | Batch 0390/390 | loss=1.231617 | top1=57.81% | top5=93.75%
# Epoch 20 avg train loss: 1.173873
#   Val: top1_acc=60.00% | top5_acc=95.01% | CE_loss=1.1323
#   [checkpoint] New best val_top1=0.599960 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 21/50 | Batch 0001/390 | loss=1.475938 | top1=56.25% | top5=89.84%
#   Epoch 21/50 | Batch 0100/390 | loss=1.298698 | top1=51.56% | top5=96.88%
#   Epoch 21/50 | Batch 0200/390 | loss=1.222466 | top1=57.81% | top5=93.75%
#   Epoch 21/50 | Batch 0300/390 | loss=1.134567 | top1=58.59% | top5=97.66%
#   Epoch 21/50 | Batch 0390/390 | loss=1.002779 | top1=64.84% | top5=96.88%
# Epoch 21 avg train loss: 1.169919
#   Val: top1_acc=60.46% | top5_acc=95.21% | CE_loss=1.1234
#   [checkpoint] New best val_top1=0.604567 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 22/50 | Batch 0001/390 | loss=1.172881 | top1=56.25% | top5=93.75%
#   Epoch 22/50 | Batch 0100/390 | loss=1.340700 | top1=52.34% | top5=96.88%
#   Epoch 22/50 | Batch 0200/390 | loss=1.108304 | top1=57.81% | top5=96.09%
#   Epoch 22/50 | Batch 0300/390 | loss=1.329901 | top1=53.12% | top5=92.97%
#   Epoch 22/50 | Batch 0390/390 | loss=1.045910 | top1=58.59% | top5=99.22%
# Epoch 22 avg train loss: 1.170187
#   Val: top1_acc=60.17% | top5_acc=95.43% | CE_loss=1.1395
#   Epoch 23/50 | Batch 0001/390 | loss=1.033238 | top1=63.28% | top5=96.09%
#   Epoch 23/50 | Batch 0100/390 | loss=1.196681 | top1=62.50% | top5=96.09%
#   Epoch 23/50 | Batch 0200/390 | loss=1.266135 | top1=53.91% | top5=93.75%
#   Epoch 23/50 | Batch 0300/390 | loss=1.408216 | top1=57.03% | top5=92.19%
#   Epoch 23/50 | Batch 0390/390 | loss=1.120587 | top1=58.59% | top5=92.97%
# Epoch 23 avg train loss: 1.221653
#   Val: top1_acc=58.05% | top5_acc=94.73% | CE_loss=1.2061
#   Epoch 24/50 | Batch 0001/390 | loss=1.434804 | top1=48.44% | top5=93.75%
#   Epoch 24/50 | Batch 0100/390 | loss=1.294746 | top1=54.69% | top5=94.53%
#   Epoch 24/50 | Batch 0200/390 | loss=1.158099 | top1=58.59% | top5=94.53%
#   Epoch 24/50 | Batch 0300/390 | loss=1.085480 | top1=64.06% | top5=93.75%
#   Epoch 24/50 | Batch 0390/390 | loss=1.274469 | top1=49.22% | top5=92.19%
# Epoch 24 avg train loss: 1.213981
#   Val: top1_acc=60.29% | top5_acc=95.30% | CE_loss=1.1346
#   Epoch 25/50 | Batch 0001/390 | loss=1.138900 | top1=59.38% | top5=96.09%
#   Epoch 25/50 | Batch 0100/390 | loss=1.263623 | top1=54.69% | top5=94.53%
#   Epoch 25/50 | Batch 0200/390 | loss=1.078819 | top1=60.16% | top5=98.44%
#   Epoch 25/50 | Batch 0300/390 | loss=1.486490 | top1=50.00% | top5=92.19%
#   Epoch 25/50 | Batch 0390/390 | loss=1.195493 | top1=57.81% | top5=96.09%
# Epoch 25 avg train loss: 1.128455
#   Val: top1_acc=61.60% | top5_acc=95.68% | CE_loss=1.0886
#   [checkpoint] New best val_top1=0.615986 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 26/50 | Batch 0001/390 | loss=0.990565 | top1=66.41% | top5=94.53%
#   Epoch 26/50 | Batch 0100/390 | loss=1.141324 | top1=60.94% | top5=95.31%
#   Epoch 26/50 | Batch 0200/390 | loss=1.157080 | top1=56.25% | top5=94.53%
#   Epoch 26/50 | Batch 0300/390 | loss=1.182568 | top1=57.03% | top5=96.88%
#   Epoch 26/50 | Batch 0390/390 | loss=1.112663 | top1=60.94% | top5=94.53%
# Epoch 26 avg train loss: 1.104820
#   Val: top1_acc=61.79% | top5_acc=95.51% | CE_loss=1.0812
#   [checkpoint] New best val_top1=0.617889 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 27/50 | Batch 0001/390 | loss=1.083539 | top1=60.94% | top5=98.44%
#   Epoch 27/50 | Batch 0100/390 | loss=0.903370 | top1=64.06% | top5=96.09%
#   Epoch 27/50 | Batch 0200/390 | loss=0.968344 | top1=65.62% | top5=96.88%
#   Epoch 27/50 | Batch 0300/390 | loss=1.109441 | top1=60.16% | top5=93.75%
#   Epoch 27/50 | Batch 0390/390 | loss=0.976814 | top1=68.75% | top5=96.09%
# Epoch 27 avg train loss: 1.068881
#   Val: top1_acc=62.55% | top5_acc=95.93% | CE_loss=1.0692
#   [checkpoint] New best val_top1=0.625501 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch 28/50 | Batch 0001/390 | loss=1.086916 | top1=58.59% | top5=96.88%
#   Epoch 28/50 | Batch 0100/390 | loss=1.078425 | top1=63.28% | top5=96.88%
#   Epoch 28/50 | Batch 0200/390 | loss=0.873147 | top1=70.31% | top5=98.44%
#   Epoch 28/50 | Batch 0300/390 | loss=1.200606 | top1=59.38% | top5=92.97%
#   Epoch 28/50 | Batch 0390/390 | loss=1.013544 | top1=65.62% | top5=94.53%
# Epoch 28 avg train loss: 1.061170
#   Val: top1_acc=63.37% | top5_acc=95.77% | CE_loss=1.0533
#   [checkpoint] New best val_top1=0.633714 — model saved to 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt'
#   Epoch
#   Epoch 49/50 | Batch 0390/390 | loss=0.930491 | top1=67.19% | top5=96.88%
# Epoch 49 avg train loss: 0.887625
#   Val: top1_acc=67.95% | top5_acc=96.62% | CE_loss=0.9284
#   Epoch 50/50 | Batch 0001/390 | loss=0.861905 | top1=67.19% | top5=98.44%
#   Epoch 50/50 | Batch 0100/390 | loss=0.871681 | top1=69.53% | top5=97.66%
#   Epoch 50/50 | Batch 0200/390 | loss=0.778919 | top1=74.22% | top5=98.44%
#   Epoch 50/50 | Batch 0300/390 | loss=0.669747 | top1=77.34% | top5=99.22%
#   Epoch 50/50 | Batch 0390/390 | loss=0.879477 | top1=67.19% | top5=97.66%
# Epoch 50 avg train loss: 0.875682
#   Val: top1_acc=68.55% | top5_acc=96.70% | CE_loss=0.8965
# Loaded best finetuned weights from 'data/notebook_test/best_student_finetuned_pruned_cifar10.pt' for evaluation.
#
# Student (pruned 50%, finetuned 50 epochs, no KD):
#   top1_acc=68.65% | top5_acc=96.85% | CE_loss=0.9070 | fwd_ms/batch=37.94 | samples=9984

# %% [markdown]
# ## Memory cleanup before distillation

# %%
import gc

# Free objects that are no longer needed before distillation.
for _var in ("ultra_teacher", "baseline_pruned_model", "student_finetuned_model", "ft_optimizer"):
    if _var in globals():
        del globals()[_var]

gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"GPU memory after cleanup: {torch.cuda.memory_allocated() / 1e6:.1f} MB allocated")
print("Memory cleanup done.")

# Reset student_cls_model to the pristine pruned state before KD training.
student_cls_model.load_state_dict(pruned_snapshot_state, strict=False)
print("student_cls_model reset to pruned (untrained) state for KD run.")
# Out:
# GPU memory after cleanup: 573.2 MB allocated
# Memory cleanup done.
# student_cls_model reset to pruned (untrained) state for KD run.

# %% [markdown]
# ## Distill teacher into pruned student on CIFAR10 images + labels

# %%
kd_config_cls = DistillationLossConfig(
    alpha=KD_ALPHA,
    temperature=KD_TEMPERATURE,
)

optimizer = torch.optim.AdamW(student_cls_model.parameters(), lr=lr, weight_decay=WEIGHT_DECAY)

distiller_cls = YOLOLogitsDistiller(
    teacher=teacher_cls_model,
    student=student_cls_model,
    kd_config=kd_config_cls,
    device=DEVICE,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    num_train_epochs=EPOCHS,
    eval_teacher=True,
)

train_history = distiller_cls.train(save_path=KD_SAVE_PATH)
loss_history     = train_history["train_total_loss"]
top1_history     = train_history["train_top1_acc"]
top5_history     = train_history["train_top5_acc"]
val_top1_history = train_history["val_top1_acc"]   # per-epoch validation top-1
val_top5_history = train_history["val_top5_acc"]   # per-epoch validation top-5
val_loss_history = train_history["val_loss"]        # per-epoch validation CE loss

# Restore best student weights before evaluation.
# strict=False: pruning masks are non-persistent buffers excluded from state_dict but
# already present and unchanged on this model instance, so only weights need restoring.
student_cls_model.load_state_dict(
    torch.load(KD_SAVE_PATH, weights_only=True), strict=False
)
print(f"Loaded best KD student weights from '{KD_SAVE_PATH}' for evaluation.")
# Out:
# Epoch 1/50
#   Batch 0001/390 | total=6.382877 | hard=2.333714 | soft=9.082319 | top1=0.1172 | top5=0.5703
#   Batch 0010/390 | total=6.330278 | hard=2.354170 | soft=8.981017 | top1=0.1484 | top5=0.6328
#   Batch 0020/390 | total=5.983382 | hard=2.138413 | soft=8.546694 | top1=0.2109 | top5=0.7031
#   Batch 0030/390 | total=6.153396 | hard=2.288463 | soft=8.730017 | top1=0.1406 | top5=0.6484
#   Batch 0040/390 | total=5.677868 | hard=2.104262 | soft=8.060272 | top1=0.1641 | top5=0.7812
#   Batch 0050/390 | total=5.606477 | hard=2.125659 | soft=7.927022 | top1=0.1797 | top5=0.7500
#   Batch 0060/390 | total=5.464918 | hard=2.163046 | soft=7.666164 | top1=0.1953 | top5=0.7891
#   Batch 0070/390 | total=5.589056 | hard=2.111524 | soft=7.907410 | top1=0.1797 | top5=0.7188
#   Batch 0080/390 | total=5.766648 | hard=2.061808 | soft=8.236541 | top1=0.2188 | top5=0.7656
#   Batch 0370/390 | total=4.551309 | hard=1.797739 | soft=6.387023 | top1=0.3203 | top5=0.8750
#   Batch 0380/390 | total=4.871095 | hard=1.908210 | soft=6.846351 | top1=0.3125 | top5=0.8125
#   Batch 0390/390 | total=4.845218 | hard=1.991906 | soft=6.747426 | top1=0.2812 | top5=0.7734
#   Val: top1=30.65% | top5=82.88% | CE_loss=2.007332
#   [checkpoint] New best val_top1=0.306490 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 2/50
#   Batch 0001/390 | total=5.243213 | hard=2.249370 | soft=7.239108 | top1=0.2188 | top5=0.7969
#   Batch 0010/390 | total=4.847703 | hard=1.878560 | soft=6.827132 | top1=0.2734 | top5=0.7969
#   Batch 0020/390 | total=5.391443 | hard=2.315912 | soft=7.441796 | top1=0.2656 | top5=0.7812
#   Batch 0030/390 | total=4.754839 | hard=1.935163 | soft=6.634624 | top1=0.3281 | top5=0.8438
#   Batch 0040/390 | total=4.898209 | hard=2.082343 | soft=6.775453 | top1=0.3047 | top5=0.8438
#   Batch 0050/390 | total=5.118019 | hard=2.082290 | soft=7.141838 | top1=0.2891 | top5=0.7344
#   Batch 0060/390 | total=5.015781 | hard=1.909141 | soft=7.086874 | top1=0.3672 | top5=0.8516
#   Batch 0070/390 | total=4.769025 | hard=1.984630 | soft=6.625288 | top1=0.3281 | top5=0.8047
#   Batch 0080/390 | total=4.719555 | hard=1.879035 | soft=6.613235 | top1=0.3125 | top5=0.8828
#   Batch 0090/390 | total=4.993901 | hard=2.104537 | soft=6.920143 | top1=0.2891 | top5=0.8047
#   Batch 0100/390 | total=4.683617 | hard=1.958564 | soft=6.500319 | top1=0.2812 | top5=0.8125
#   Batch 0110/390 | total=4.438239 | hard=1.764637 | soft=6.220640 | top1=0.3594 | top5=0.8828
#   Batch 0120/390 | total=4.669949 | hard=1.907996 | soft=6.511250 | top1=0.3125 | top5=0.7812
#   Batch 0130/390 | total=4.843630 | hard=2.303661 | soft=6.536942 | top1=0.2812 | top5=0.8359
#   Batch 0140/390 | total=4.845563 | hard=2.103953 | soft=6.673304 | top1=0.3438 | top5=0.8125
#   Batch 0150/390 | total=4.604345 | hard=1.994833 | soft=6.344020 | top1=0.3125 | top5=0.8438
#   Batch 0160/390 | total=5.095345 | hard=2.070425 | soft=7.111959 | top1=0.2891 | top5=0.7656
#   Batch 0170/390 | total=5.229089 | hard=2.185443 | soft=7.258185 | top1=0.2734 | top5=0.8203
#   Batch 0180/390 | total=4.847722 | hard=2.037996 | soft=6.720872 | top1=0.2891 | top5=0.8516
#   Batch 0190/390 | total=5.069381 | hard=2.388804 | soft=6.856432 | top1=0.2578 | top5=0.7969
#   Batch 0200/390 | total=4.345859 | hard=1.824554 | soft=6.026728 | top1=0.3438 | top5=0.8516
#   Batch 0210/390 | total=4.095440 | hard=1.722332 | soft=5.677512 | top1=0.3516 | top5=0.9062
#   Batch 0220/390 | total=4.896996 | hard=2.005795 | soft=6.824462 | top1=0.3125 | top5=0.8281
#   Batch 0230/390 | total=4.861067 | hard=2.042718 | soft=6.739967 | top1=0.3281 | top5=0.8984
#   Batch 0270/390 | total=4.342124 | hard=1.934682 | soft=5.947086 | top1=0.4219 | top5=0.9062
#   Batch 0280/390 | total=4.057551 | hard=1.954416 | soft=5.459641 | top1=0.3750 | top5=0.8594
#   Batch 0290/390 | total=3.938344 | hard=1.624267 | soft=5.481061 | top1=0.4453 | top5=0.8750
#   Batch 0300/390 | total=3.653393 | hard=1.498673 | soft=5.089872 | top1=0.4375 | top5=0.8750
#   Batch 0310/390 | total=4.561116 | hard=2.033483 | soft=6.246204 | top1=0.3672 | top5=0.8906
#   Batch 0320/390 | total=3.984718 | hard=1.785689 | soft=5.450737 | top1=0.4375 | top5=0.8594
#   Batch 0330/390 | total=4.102849 | hard=1.884397 | soft=5.581818 | top1=0.4219 | top5=0.8672
#   Batch 0340/390 | total=4.407814 | hard=2.064997 | soft=5.969692 | top1=0.4219 | top5=0.8125
#   Batch 0350/390 | total=4.023877 | hard=1.983074 | soft=5.384413 | top1=0.4062 | top5=0.8672
#   Batch 0360/390 | total=3.839033 | hard=1.641512 | soft=5.304047 | top1=0.4844 | top5=0.9062
#   Batch 0370/390 | total=3.783028 | hard=1.648408 | soft=5.206108 | top1=0.4219 | top5=0.9375
#   Batch 0380/390 | total=3.800228 | hard=1.749066 | soft=5.167668 | top1=0.4688 | top5=0.9062
#   Batch 0390/390 | total=4.185829 | hard=1.829957 | soft=5.756410 | top1=0.4453 | top5=0.8594
#   Val: top1=45.66% | top5=89.95% | CE_loss=1.687803
#   [checkpoint] New best val_top1=0.456631 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 5/50
#   Batch 0001/390 | total=3.555699 | hard=1.558596 | soft=4.887101 | top1=0.4141 | top5=0.9141
#   Batch 0010/390 | total=3.858530 | hard=1.621125 | soft=5.350132 | top1=0.4297 | top5=0.9297
#   Batch 0020/390 | total=4.440155 | hard=1.996252 | soft=6.069423 | top1=0.3984 | top5=0.8516
#   Batch 0030/390 | total=3.844507 | hard=1.721414 | soft=5.259902 | top1=0.4219 | top5=0.9219
#   Batch 0040/390 | total=3.670737 | hard=1.637489 | soft=5.026235 | top1=0.4531 | top5=0.9375
#   Batch 0050/390 | total=3.585504 | hard=1.459562 | soft=5.002799 | top1=0.5078 | top5=0.9297
#   Batch 0060/390 | total=3.773792 | hard=1.703852 | soft=5.153751 | top1=0.3984 | top5=0.9219
#   Batch 0070/390 | total=3.790740 | hard=1.702138 | soft=5.183142 | top1=0.5469 | top5=0.8984
#   Batch 0080/390 | total=3.644072 | hard=1.601112 | soft=5.006045 | top1=0.4297 | top5=0.9375
#   Batch 0090/390 | total=4.135618 | hard=1.838458 | soft=5.667058 | top1=0.4453 | top5=0.8828
#   Batch 0100/390 | total=4.049231 | hard=1.754810 | soft=5.578844 | top1=0.4219 | top5=0.8984
#   Batch 0110/390 | total=4.456484 | hard=2.067398 | soft=6.049208 | top1=0.3984 | top5=0.8984
#   Batch 0120/390 | total=4.005848 | hard=1.790385 | soft=5.482823 | top1=0.4766 | top5=0.9141
#   Batch 0130/390 | total=3.744875 | hard=1.673981 | soft=5.125470 | top1=0.4688 | top5=0.9141
#   Batch 0140/390 | total=3.926120 | hard=1.844742 | soft=5.313704 | top1=0.4453 | top5=0.8594
#   Batch 0150/390 | total=3.767403 | hard=1.722812 | soft=5.130464 | top1=0.3750 | top5=0.9219
#   Batch 0160/390 | total=3.592424 | hard=1.515948 | soft=4.976741 | top1=0.4844 | top5=0.9141
#   Batch 0170/390 | total=3.898135 | hard=1.820382 | soft=5.283304 | top1=0.4531 | top5=0.8906
#   Batch 0180/390 | total=3.846814 | hard=1.651405 | soft=5.310420 | top1=0.4453 | top5=0.9375
#   Batch 0190/390 | total=3.855607 | hard=1.632340 | soft=5.337784 | top1=0.4844 | top5=0.9062
#   Batch 0200/390 | total=3.612503 | hard=1.611624 | soft=4.946423 | top1=0.4688 | top5=0.8906
#   Batch 0210/390 | total=4.221953 | hard=2.014642 | soft=5.693495 | top1=0.3906 | top5=0.8281
#   Batch 0220/390 | total=3.680475 | hard=1.637550 | soft=5.042425 | top1=0.4609 | top5=0.9219
#   Batch 0230/390 | total=3.998854 | hard=1.859470 | soft=5.425110 | top1=0.4453 | top5=0.9141
#   Batch 0240/390 | total=3.773505 | hard=1.691468 | soft=5.161529 | top1=0.4766 | top5=0.8672
#   Batch 0250/390 | total=3.447926 | hard=1.509734 | soft=4.740054 | top1=0.5078 | top5=0.9297
#   Batch 0260/390 | total=3.476091 | hard=1.550346 | soft=4.759920 | top1=0.4609 | top5=0.9297
#   Batch 0270/390 | total=3.482293 | hard=1.740406 | soft=4.643550 | top1=0.4609 | top5=0.8750
#   Batch 0280/390 | total=3.548444 | hard=1.599244 | soft=4.847911 | top1=0.5000 | top5=0.9062
#   Batch 0290/390 | total=4.214410 | hard=1.812847 | soft=5.815452 | top1=0.4453 | top5=0.8594
#   Batch 0300/390 | total=3.455873 | hard=1.421850 | soft=4.811887 | top1=0.5078 | top5=0.9141
#   Batch 0310/390 | total=3.844166 | hard=1.788173 | soft=5.214828 | top1=0.4531 | top5=0.8672
#   Batch 0320/390 | total=3.890546 | hard=1.889770 | soft=5.224396 | top1=0.3750 | top5=0.9375
#   Batch 0330/390 | total=4.077294 | hard=1.878087 | soft=5.543432 | top1=0.4141 | top5=0.8906
#   Batch 0340/390 | total=3.374401 | hard=1.348869 | soft=4.724755 | top1=0.5547 | top5=0.9375
#   Batch 0350/390 | total=3.683130 | hard=1.429592 | soft=5.185488 | top1=0.5625 | top5=0.9219
#   Batch 0360/390 | total=3.551127 | hard=1.482464 | soft=4.930236 | top1=0.5078 | top5=0.8984
#   Batch 0370/390 | total=4.146138 | hard=2.065275 | soft=5.533380 | top1=0.4141 | top5=0.8906
#   Batch 0380/390 | total=4.176020 | hard=2.066589 | soft=5.582308 | top1=0.3984 | top5=0.8594
#   Batch 0390/390 | total=3.269853 | hard=1.419966 | soft=4.503110 | top1=0.5859 | top5=0.8984
#   Val: top1=48.93% | top5=91.37% | CE_loss=1.643933
#   [checkpoint] New best val_top1=0.489283 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 6/50
#   Batch 0001/390 | total=3.603142 | hard=1.524641 | soft=4.988810 | top1=0.5469 | top5=0.9297
#   Batch 0010/390 | total=3.605766 | hard=1.683467 | soft=4.887299 | top1=0.4922 | top5=0.8984
#   Batch 0020/390 | total=3.439983 | hard=1.564313 | soft=4.690429 | top1=0.4922 | top5=0.9375
#   Batch 0030/390 | total=3.861161 | hard=1.676973 | soft=5.317286 | top1=0.4531 | top5=0.9531
#   Batch 0040/390 | total=3.611021 | hard=1.644349 | soft=4.922134 | top1=0.5000 | top5=0.9375
#   Batch 0050/390 | total=3.712564 | hard=1.601092 | soft=5.120212 | top1=0.5391 | top5=0.9219
#   Batch 0060/390 | total=3.300088 | hard=1.374639 | soft=4.583721 | top1=0.5234 | top5=0.8828
#   Batch 0070/390 | total=3.144436 | hard=1.503176 | soft=4.238609 | top1=0.4766 | top5=0.9062
#   Batch 0080/390 | total=4.001454 | hard=1.885677 | soft=5.411972 | top1=0.4297 | top5=0.8672
#   Batch 0090/390 | total=3.527801 | hard=1.666233 | soft=4.768846 | top1=0.5000 | top5=0.9141
#   Batch 0100/390 | total=3.336825 | hard=1.410006 | soft=4.621370 | top1=0.6016 | top5=0.9062
#   Batch 0110/390 | total=3.513784 | hard=1.562208 | soft=4.814835 | top1=0.5078 | top5=0.9375
#   Batch 0120/390 | total=4.092796 | hard=1.930977 | soft=5.534008 | top1=0.4062 | top5=0.8906
#   Batch 0130/390 | total=3.523788 | hard=1.583840 | soft=4.817088 | top1=0.4531 | top5=0.9297
#   Batch 0140/390 | total=3.399616 | hard=1.609499 | soft=4.593027 | top1=0.4688 | top5=0.9219
#   Batch 0150/390 | total=3.482944 | hard=1.521940 | soft=4.790279 | top1=0.4844 | top5=0.9297
#   Batch 0160/390 | total=3.632099 | hard=1.692571 | soft=4.925117 | top1=0.4766 | top5=0.9219
#   Batch 0170/390 | total=3.365504 | hard=1.593253 | soft=4.547005 | top1=0.4922 | top5=0.9062
#   Batch 0180/390 | total=3.687639 | hard=1.932098 | soft=4.857999 | top1=0.5000 | top5=0.8984
#   Batch 0190/390 | total=4.684855 | hard=2.159313 | soft=6.368550 | top1=0.4219 | top5=0.8359
#   Batch 0200/390 | total=3.399409 | hard=1.334214 | soft=4.776206 | top1=0.5625 | top5=0.9141
#   Batch 0210/390 | total=3.451795 | hard=1.520852 | soft=4.739090 | top1=0.5312 | top5=0.8828
#   Batch 0220/390 | total=3.395765 | hard=1.435873 | soft=4.702359 | top1=0.5000 | top5=0.9375
#   Batch 0230/390 | total=4.087305 | hard=1.998356 | soft=5.479937 | top1=0.4297 | top5=0.9375
#   Batch 0240/390 | total=3.689787 | hard=1.683182 | soft=5.027524 | top1=0.5000 | top5=0.8984
#   Batch 0250/390 | total=3.550207 | hard=1.653592 | soft=4.814617 | top1=0.4688 | top5=0.9375
#   Batch 0260/390 | total=3.687505 | hard=1.879060 | soft=4.893135 | top1=0.4453 | top5=0.8750
#   Batch 0270/390 | total=3.638364 | hard=1.784017 | soft=4.874595 | top1=0.4375 | top5=0.9062
#   Batch 0280/390 | total=4.095570 | hard=2.105337 | soft=5.422391 | top1=0.4219 | top5=0.9062
#   Batch 0290/390 | total=3.802479 | hard=1.743049 | soft=5.175432 | top1=0.4766 | top5=0.9062
#   Batch 0300/390 | total=3.731030 | hard=1.673122 | soft=5.102969 | top1=0.4609 | top5=0.9453
#   Batch 0310/390 | total=3.444139 | hard=1.591640 | soft=4.679138 | top1=0.4922 | top5=0.9219
#   Batch 0320/390 | total=3.461471 | hard=1.611275 | soft=4.694935 | top1=0.4922 | top5=0.9297
#   Batch 0330/390 | total=3.633726 | hard=1.535588 | soft=5.032484 | top1=0.4922 | top5=0.9141
#   Batch 0340/390 | total=3.219777 | hard=1.506916 | soft=4.361684 | top1=0.4688 | top5=0.9219
#   Batch 0350/390 | total=3.911541 | hard=1.853108 | soft=5.283830 | top1=0.4688 | top5=0.8984
#   Batch 0360/390 | total=3.836896 | hard=1.923072 | soft=5.112778 | top1=0.4766 | top5=0.8828
#   Batch 0370/390 | total=3.274956 | hard=1.399532 | soft=4.525238 | top1=0.5469 | top5=0.9219
#   Batch 0380/390 | total=3.369115 | hard=1.538779 | soft=4.589338 | top1=0.5391 | top5=0.8984
#   Batch 0390/390 | total=3.073149 | hard=1.415659 | soft=4.178142 | top1=0.5234 | top5=0.9609
#   Val: top1=51.21% | top5=91.80% | CE_loss=1.589995
#   [checkpoint] New best val_top1=0.512119 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 7/50
#   Batch 0001/390 | total=3.135436 | hard=1.365501 | soft=4.315392 | top1=0.5547 | top5=0.9297
#   Batch 0010/390 | total=3.513834 | hard=1.550401 | soft=4.822789 | top1=0.5312 | top5=0.8828
#   Batch 0020/390 | total=3.561486 | hard=1.690862 | soft=4.808569 | top1=0.4531 | top5=0.9141
#   Batch 0030/390 | total=3.071505 | hard=1.237426 | soft=4.294223 | top1=0.5859 | top5=0.9531
#   Batch 0040/390 | total=3.651041 | hard=1.843700 | soft=4.855934 | top1=0.4297 | top5=0.9141
#   Batch 0050/390 | total=3.854208 | hard=1.794851 | soft=5.227112 | top1=0.4141 | top5=0.8828
#   Batch 0060/390 | total=3.474600 | hard=1.582224 | soft=4.736185 | top1=0.5156 | top5=0.9453
#   Batch 0070/390 | total=3.224951 | hard=1.560372 | soft=4.334669 | top1=0.4922 | top5=0.9297
#   Batch 0080/390 | total=3.594060 | hard=1.628911 | soft=4.904160 | top1=0.4688 | top5=0.9062
#   Batch 0090/390 | total=3.475199 | hard=1.860320 | soft=4.551784 | top1=0.4062 | top5=0.9062
#   Batch 0100/390 | total=3.512117 | hard=1.688894 | soft=4.727598 | top1=0.5000 | top5=0.9141
#   Batch 0110/390 | total=3.509906 | hard=1.613257 | soft=4.774338 | top1=0.4688 | top5=0.9141
#   Batch 0120/390 | total=3.664817 | hard=1.592632 | soft=5.046273 | top1=0.5000 | top5=0.9453
#   Batch 0130/390 | total=3.575973 | hard=1.806682 | soft=4.755499 | top1=0.4609 | top5=0.9297
#   Batch 0140/390 | total=3.324273 | hard=1.364883 | soft=4.630533 | top1=0.5391 | top5=0.9453
#   Batch 0150/390 | total=3.600390 | hard=1.714469 | soft=4.857671 | top1=0.5078 | top5=0.8828
#   Batch 0160/390 | total=3.102518 | hard=1.350609 | soft=4.270457 | top1=0.5078 | top5=0.9453
#   Batch 0170/390 | total=3.978036 | hard=1.967332 | soft=5.318505 | top1=0.4453 | top5=0.8750
#   Batch 0180/390 | total=2.968223 | hard=1.202013 | soft=4.145696 | top1=0.5625 | top5=0.9453
#   Batch 0190/390 | total=3.727143 | hard=1.826589 | soft=4.994179 | top1=0.3906 | top5=0.9141
#   Batch 0200/390 | total=3.438542 | hard=1.580415 | soft=4.677293 | top1=0.4453 | top5=0.9141
#   Batch 0210/390 | total=3.491161 | hard=1.461007 | soft=4.844596 | top1=0.5078 | top5=0.9375
#   Batch 0220/390 | total=3.024434 | hard=1.371844 | soft=4.126160 | top1=0.5547 | top5=0.9688
#   Batch 0230/390 | total=3.890665 | hard=1.801861 | soft=5.283200 | top1=0.4531 | top5=0.9219
#   Batch 0240/390 | total=3.225878 | hard=1.482247 | soft=4.388298 | top1=0.5625 | top5=0.9062
#   Batch 0250/390 | total=3.695190 | hard=1.654444 | soft=5.055687 | top1=0.4844 | top5=0.8828
#   Batch 0260/390 | total=3.741095 | hard=1.669084 | soft=5.122436 | top1=0.4688 | top5=0.8984
#   Batch 0270/390 | total=3.339993 | hard=1.527787 | soft=4.548130 | top1=0.5312 | top5=0.9219
#   Batch 0280/390 | total=3.515663 | hard=1.692673 | soft=4.730990 | top1=0.5391 | top5=0.9062
#   Batch 0290/390 | total=3.644899 | hard=1.893596 | soft=4.812435 | top1=0.4531 | top5=0.9375
#   Batch 0300/390 | total=3.643395 | hard=1.757392 | soft=4.900730 | top1=0.4922 | top5=0.9219
#   Batch 0310/390 | total=3.467883 | hard=1.520519 | soft=4.766126 | top1=0.5391 | top5=0.9062
#   Batch 0320/390 | total=3.194698 | hard=1.647746 | soft=4.225999 | top1=0.5156 | top5=0.9062
#   Batch 0330/390 | total=3.479611 | hard=1.633885 | soft=4.710095 | top1=0.5156 | top5=0.9219
#   Batch 0340/390 | total=3.287784 | hard=1.434224 | soft=4.523491 | top1=0.5469 | top5=0.8906
#   Batch 0350/390 | total=3.297024 | hard=1.460752 | soft=4.521205 | top1=0.5234 | top5=0.9219
#   Batch 0360/390 | total=3.435036 | hard=1.490087 | soft=4.731669 | top1=0.5000 | top5=0.9375
#   Batch 0370/390 | total=2.967326 | hard=1.305019 | soft=4.075531 | top1=0.5781 | top5=0.9531
#   Batch 0380/390 | total=3.852693 | hard=1.701798 | soft=5.286622 | top1=0.5078 | top5=0.8828
#   Batch 0390/390 | total=3.237082 | hard=1.435100 | soft=4.438404 | top1=0.5156 | top5=0.9219
#   Val: top1=53.06% | top5=92.80% | CE_loss=1.532705
#   [checkpoint] New best val_top1=0.530649 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 8/50
#   Batch 0001/390 | total=3.151515 | hard=1.457255 | soft=4.281022 | top1=0.5469 | top5=0.8984
#   Batch 0010/390 | total=3.105020 | hard=1.407686 | soft=4.236575 | top1=0.5391 | top5=0.9453
#   Batch 0020/390 | total=3.450352 | hard=1.506949 | soft=4.745954 | top1=0.5156 | top5=0.9297
#   Batch 0030/390 | total=3.794861 | hard=1.926597 | soft=5.040370 | top1=0.4375 | top5=0.8828
#   Batch 0040/390 | total=3.258945 | hard=1.387156 | soft=4.506804 | top1=0.5703 | top5=0.9219
#   Batch 0050/390 | total=3.191351 | hard=1.367485 | soft=4.407262 | top1=0.5391 | top5=0.9297
#   Batch 0060/390 | total=2.965532 | hard=1.343503 | soft=4.046884 | top1=0.5547 | top5=0.9297
#   Batch 0070/390 | total=3.295223 | hard=1.624678 | soft=4.408920 | top1=0.4922 | top5=0.9609
#   Batch 0080/390 | total=3.231235 | hard=1.610305 | soft=4.311854 | top1=0.5312 | top5=0.9609
#   Batch 0090/390 | total=3.389935 | hard=1.612754 | soft=4.574722 | top1=0.4922 | top5=0.8828
#   Batch 0100/390 | total=3.102713 | hard=1.362037 | soft=4.263164 | top1=0.5703 | top5=0.9297
#   Batch 0110/390 | total=3.313510 | hard=1.649951 | soft=4.422550 | top1=0.5000 | top5=0.9297
#   Batch 0120/390 | total=3.392449 | hard=1.549419 | soft=4.621135 | top1=0.5469 | top5=0.9297
#   Batch 0130/390 | total=3.748904 | hard=1.866991 | soft=5.003512 | top1=0.4688 | top5=0.8828
#   Batch 0140/390 | total=2.995906 | hard=1.277900 | soft=4.141243 | top1=0.6094 | top5=0.9062
#   Batch 0150/390 | total=3.091286 | hard=1.464768 | soft=4.175631 | top1=0.5703 | top5=0.9062
#   Batch 0160/390 | total=3.146078 | hard=1.476943 | soft=4.258835 | top1=0.5312 | top5=0.9141
#   Batch 0170/390 | total=3.196432 | hard=1.490372 | soft=4.333805 | top1=0.5781 | top5=0.9297
#   Batch 0180/390 | total=3.147611 | hard=1.553935 | soft=4.210061 | top1=0.5391 | top5=0.9531
#   Batch 0190/390 | total=3.327198 | hard=1.474686 | soft=4.562205 | top1=0.5312 | top5=0.9375
#   Batch 0200/390 | total=3.104500 | hard=1.390754 | soft=4.246996 | top1=0.5625 | top5=0.8984
#   Batch 0210/390 | total=3.457036 | hard=1.586706 | soft=4.703923 | top1=0.4844 | top5=0.9062
#   Batch 0220/390 | total=3.407552 | hard=1.563705 | soft=4.636783 | top1=0.4688 | top5=0.9531
#   Batch 0230/390 | total=3.166893 | hard=1.320054 | soft=4.398118 | top1=0.5391 | top5=0.9297
#   Batch 0240/390 | total=3.409097 | hard=1.624911 | soft=4.598554 | top1=0.4766 | top5=0.9062
#   Batch 0250/390 | total=3.356735 | hard=1.464525 | soft=4.618208 | top1=0.5156 | top5=0.9375
#   Batch 0260/390 | total=3.676012 | hard=1.907983 | soft=4.854697 | top1=0.4609 | top5=0.8984
#   Batch 0270/390 | total=3.087037 | hard=1.427933 | soft=4.193106 | top1=0.5625 | top5=0.9375
#   Batch 0280/390 | total=3.353803 | hard=1.639919 | soft=4.496392 | top1=0.4766 | top5=0.8984
#   Batch 0290/390 | total=3.170549 | hard=1.464232 | soft=4.308094 | top1=0.5781 | top5=0.8984
#   Batch 0300/390 | total=3.100113 | hard=1.405350 | soft=4.229954 | top1=0.4688 | top5=0.9375
#   Batch 0310/390 | total=3.146112 | hard=1.430284 | soft=4.289997 | top1=0.5234 | top5=0.9531
#   Batch 0320/390 | total=3.564954 | hard=1.564388 | soft=4.898664 | top1=0.5078 | top5=0.8984
#   Batch 0330/390 | total=2.943742 | hard=1.363553 | soft=3.997201 | top1=0.5391 | top5=0.9453
#   Batch 0340/390 | total=3.214430 | hard=1.489540 | soft=4.364356 | top1=0.5000 | top5=0.9141
#   Batch 0350/390 | total=2.960917 | hard=1.334246 | soft=4.045365 | top1=0.6016 | top5=0.9531
#   Batch 0360/390 | total=3.319034 | hard=1.613570 | soft=4.456009 | top1=0.5234 | top5=0.8828
#   Batch 0370/390 | total=3.843524 | hard=1.832580 | soft=5.184152 | top1=0.4688 | top5=0.8984
#   Batch 0380/390 | total=3.241494 | hard=1.576466 | soft=4.351512 | top1=0.5156 | top5=0.9141
#   Batch 0390/390 | total=3.241021 | hard=1.506838 | soft=4.397142 | top1=0.5156 | top5=0.9453
#   Val: top1=53.87% | top5=93.07% | CE_loss=1.541584
#   [checkpoint] New best val_top1=0.538662 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 9/50
#   Batch 0001/390 | total=3.510321 | hard=1.738402 | soft=4.691600 | top1=0.4375 | top5=0.8984
#   Batch 0010/390 | total=3.223277 | hard=1.523099 | soft=4.356728 | top1=0.5312 | top5=0.9531
#   Batch 0020/390 | total=2.957127 | hard=1.416760 | soft=3.984038 | top1=0.5547 | top5=0.9453
#   Batch 0030/390 | total=3.334336 | hard=1.500632 | soft=4.556806 | top1=0.5859 | top5=0.8828
#   Batch 0040/390 | total=3.376287 | hard=1.578559 | soft=4.574772 | top1=0.5000 | top5=0.9141
#   Batch 0050/390 | total=3.573085 | hard=1.748264 | soft=4.789632 | top1=0.5156 | top5=0.9062
#   Batch 0060/390 | total=3.222264 | hard=1.515366 | soft=4.360196 | top1=0.5156 | top5=0.9375
#   Batch 0070/390 | total=3.356711 | hard=1.640271 | soft=4.501004 | top1=0.5156 | top5=0.9297
#   Batch 0080/390 | total=3.192495 | hard=1.478984 | soft=4.334836 | top1=0.5703 | top5=0.9141
#   Batch 0090/390 | total=3.313767 | hard=1.597678 | soft=4.457827 | top1=0.5312 | top5=0.9297
#   Batch 0100/390 | total=3.137931 | hard=1.444048 | soft=4.267186 | top1=0.5391 | top5=0.9375
#   Batch 0110/390 | total=3.512938 | hard=1.604662 | soft=4.785121 | top1=0.5469 | top5=0.9297
#   Batch 0120/390 | total=3.356922 | hard=1.583402 | soft=4.539268 | top1=0.5000 | top5=0.9141
#   Batch 0130/390 | total=3.135753 | hard=1.551211 | soft=4.192114 | top1=0.5234 | top5=0.9375
#   Batch 0140/390 | total=2.770237 | hard=1.192450 | soft=3.822096 | top1=0.5938 | top5=0.9375
#   Batch 0150/390 | total=2.993084 | hard=1.188530 | soft=4.196119 | top1=0.6250 | top5=0.9531
#   Batch 0160/390 | total=3.360140 | hard=1.639021 | soft=4.507552 | top1=0.5234 | top5=0.8906
#   Batch 0170/390 | total=3.187545 | hard=1.610504 | soft=4.238904 | top1=0.4844 | top5=0.9219
#   Batch 0180/390 | total=3.356031 | hard=1.636456 | soft=4.502414 | top1=0.5391 | top5=0.9453
#   Batch 0190/390 | total=3.222209 | hard=1.608382 | soft=4.298095 | top1=0.4844 | top5=0.9531
#   Batch 0200/390 | total=3.247439 | hard=1.532760 | soft=4.390558 | top1=0.5469 | top5=0.9375
#   Batch 0210/390 | total=3.493523 | hard=1.612364 | soft=4.747628 | top1=0.5234 | top5=0.9141
#   Batch 0220/390 | total=2.793684 | hard=1.270558 | soft=3.809100 | top1=0.5703 | top5=0.9609
#   Batch 0230/390 | total=2.988426 | hard=1.442256 | soft=4.019206 | top1=0.5312 | top5=0.9609
#   Batch 0240/390 | total=2.934017 | hard=1.484397 | soft=3.900431 | top1=0.5469 | top5=0.9453
#   Batch 0250/390 | total=3.638851 | hard=1.674855 | soft=4.948181 | top1=0.5469 | top5=0.9141
#   Batch 0260/390 | total=3.332911 | hard=1.761106 | soft=4.380781 | top1=0.5469 | top5=0.9297
#   Batch 0270/390 | total=3.239419 | hard=1.521933 | soft=4.384409 | top1=0.5781 | top5=0.9141
#   Batch 0280/390 | total=3.312121 | hard=1.788026 | soft=4.328184 | top1=0.4922 | top5=0.9375
#   Batch 0290/390 | total=3.628843 | hard=1.886345 | soft=4.790507 | top1=0.4766 | top5=0.8984
#   Batch 0300/390 | total=3.004696 | hard=1.381495 | soft=4.086830 | top1=0.5781 | top5=0.9531
#   Batch 0310/390 | total=3.570197 | hard=1.803107 | soft=4.748258 | top1=0.5000 | top5=0.9141
#   Batch 0320/390 | total=3.249875 | hard=1.684165 | soft=4.293682 | top1=0.5078 | top5=0.9453
#   Batch 0330/390 | total=3.292517 | hard=1.460655 | soft=4.513759 | top1=0.5391 | top5=0.9375
#   Batch 0340/390 | total=3.394180 | hard=1.794172 | soft=4.460852 | top1=0.4688 | top5=0.8984
#   Batch 0350/390 | total=3.241355 | hard=1.355766 | soft=4.498415 | top1=0.5625 | top5=0.9219
#   Batch 0360/390 | total=2.798165 | hard=1.198343 | soft=3.864713 | top1=0.5859 | top5=0.9297
#   Batch 0370/390 | total=3.317441 | hard=1.780369 | soft=4.342156 | top1=0.4531 | top5=0.9531
#   Batch 0380/390 | total=3.241923 | hard=1.474398 | soft=4.420273 | top1=0.5234 | top5=0.9062
#   Batch 0390/390 | total=2.952891 | hard=1.499536 | soft=3.921795 | top1=0.5781 | top5=0.9531
#   Val: top1=55.63% | top5=93.37% | CE_loss=1.480777
#   [checkpoint] New best val_top1=0.556290 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 10/50
#   Batch 0001/390 | total=3.076797 | hard=1.473403 | soft=4.145726 | top1=0.5078 | top5=0.9297
#   Batch 0010/390 | total=3.409070 | hard=1.586426 | soft=4.624166 | top1=0.5000 | top5=0.9531
#   Batch 0020/390 | total=2.905361 | hard=1.512715 | soft=3.833791 | top1=0.5625 | top5=0.9375
#   Batch 0030/390 | total=3.480355 | hard=1.719276 | soft=4.654408 | top1=0.4453 | top5=0.9375
#   Batch 0040/390 | total=3.018691 | hard=1.446178 | soft=4.067033 | top1=0.5547 | top5=0.9141
#   Batch 0050/390 | total=2.959887 | hard=1.268667 | soft=4.087367 | top1=0.5781 | top5=0.9297
#   Batch 0060/390 | total=2.762122 | hard=1.337877 | soft=3.711619 | top1=0.5547 | top5=0.9453
#   Batch 0070/390 | total=3.122970 | hard=1.406365 | soft=4.267374 | top1=0.5625 | top5=0.8984
#   Batch 0080/390 | total=3.130741 | hard=1.580788 | soft=4.164042 | top1=0.5469 | top5=0.9297
#   Batch 0090/390 | total=3.260921 | hard=1.577906 | soft=4.382932 | top1=0.5312 | top5=0.9141
#   Batch 0100/390 | total=3.522842 | hard=1.723758 | soft=4.722232 | top1=0.5234 | top5=0.8672
#   Batch 0110/390 | total=2.983216 | hard=1.521921 | soft=3.957412 | top1=0.5547 | top5=0.9375
#   Batch 0120/390 | total=3.027790 | hard=1.524947 | soft=4.029685 | top1=0.6094 | top5=0.9062
#   Batch 0130/390 | total=2.722481 | hard=1.199495 | soft=3.737804 | top1=0.6172 | top5=0.9219
#   Batch 0140/390 | total=2.877814 | hard=1.323073 | soft=3.914308 | top1=0.6016 | top5=0.9453
#   Batch 0150/390 | total=2.920995 | hard=1.294987 | soft=4.005001 | top1=0.5938 | top5=0.9375
#   Batch 0160/390 | total=2.921814 | hard=1.408798 | soft=3.930491 | top1=0.5156 | top5=0.9453
#   Batch 0170/390 | total=2.698771 | hard=1.198614 | soft=3.698875 | top1=0.6250 | top5=0.9219
#   Batch 0180/390 | total=3.309238 | hard=1.595268 | soft=4.451884 | top1=0.5625 | top5=0.9219
#   Batch 0190/390 | total=3.730618 | hard=1.963133 | soft=4.908941 | top1=0.4531 | top5=0.9141
#   Batch 0200/390 | total=3.329397 | hard=1.635535 | soft=4.458638 | top1=0.5156 | top5=0.9219
#   Batch 0210/390 | total=3.027749 | hard=1.527068 | soft=4.028203 | top1=0.5156 | top5=0.9531
#   Batch 0220/390 | total=2.911862 | hard=1.381808 | soft=3.931898 | top1=0.5625 | top5=0.9297
#   Batch 0230/390 | total=2.936598 | hard=1.690387 | soft=3.767405 | top1=0.5391 | top5=0.9062
#   Batch 0240/390 | total=2.924301 | hard=1.426368 | soft=3.922923 | top1=0.5078 | top5=0.9375
#   Batch 0250/390 | total=3.308640 | hard=1.609230 | soft=4.441580 | top1=0.5469 | top5=0.9141
#   Batch 0260/390 | total=2.970077 | hard=1.542903 | soft=3.921527 | top1=0.5469 | top5=0.9375
#   Batch 0270/390 | total=3.088601 | hard=1.520719 | soft=4.133855 | top1=0.5234 | top5=0.9297
#   Batch 0280/390 | total=2.932010 | hard=1.330189 | soft=3.999891 | top1=0.6016 | top5=0.9375
#   Batch 0290/390 | total=3.206278 | hard=1.671306 | soft=4.229593 | top1=0.4922 | top5=0.9219
#   Batch 0300/390 | total=2.696917 | hard=1.288651 | soft=3.635760 | top1=0.5859 | top5=0.9531
#   Batch 0310/390 | total=3.014461 | hard=1.470441 | soft=4.043808 | top1=0.5625 | top5=0.9453
#   Batch 0320/390 | total=2.674953 | hard=1.233898 | soft=3.635656 | top1=0.6406 | top5=0.9141
#   Batch 0330/390 | total=3.000633 | hard=1.533911 | soft=3.978448 | top1=0.5547 | top5=0.8984
#   Batch 0340/390 | total=3.136546 | hard=1.458979 | soft=4.254924 | top1=0.5859 | top5=0.9531
#   Batch 0350/390 | total=2.834830 | hard=1.323771 | soft=3.842203 | top1=0.5938 | top5=0.9219
#   Batch 0360/390 | total=2.651800 | hard=1.344776 | soft=3.523149 | top1=0.5938 | top5=0.9531
#   Batch 0370/390 | total=2.747823 | hard=1.330833 | soft=3.692482 | top1=0.5781 | top5=0.9453
#   Batch 0380/390 | total=3.021896 | hard=1.503946 | soft=4.033862 | top1=0.5703 | top5=0.9375
#   Batch 0390/390 | total=3.378032 | hard=1.628399 | soft=4.544454 | top1=0.5156 | top5=0.9375
#   Val: top1=57.18% | top5=93.73% | CE_loss=1.398206
#   [checkpoint] New best val_top1=0.571815 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 11/50
#   Batch 0001/390 | total=2.948151 | hard=1.365637 | soft=4.003160 | top1=0.5781 | top5=0.9297
#   Batch 0010/390 | total=3.518011 | hard=1.755474 | soft=4.693035 | top1=0.4609 | top5=0.9219
#   Batch 0020/390 | total=2.826457 | hard=1.390282 | soft=3.783906 | top1=0.5547 | top5=0.9453
#   Batch 0030/390 | total=3.197248 | hard=1.505221 | soft=4.325266 | top1=0.5000 | top5=0.9531
#   Batch 0040/390 | total=2.774827 | hard=1.435715 | soft=3.667568 | top1=0.5547 | top5=0.9453
#   Batch 0050/390 | total=2.921898 | hard=1.374250 | soft=3.953663 | top1=0.5703 | top5=0.9766
#   Batch 0060/390 | total=3.388364 | hard=1.676119 | soft=4.529860 | top1=0.5156 | top5=0.8906
#   Batch 0070/390 | total=2.908045 | hard=1.270222 | soft=3.999927 | top1=0.5547 | top5=0.9453
#   Batch 0080/390 | total=2.585493 | hard=1.110076 | soft=3.569104 | top1=0.6875 | top5=0.9453
#   Batch 0090/390 | total=3.254912 | hard=1.656876 | soft=4.320270 | top1=0.5234 | top5=0.9766
#   Batch 0100/390 | total=3.249134 | hard=1.702379 | soft=4.280305 | top1=0.5156 | top5=0.9375
#   Batch 0110/390 | total=3.379273 | hard=1.709390 | soft=4.492529 | top1=0.5469 | top5=0.8828
#   Batch 0120/390 | total=3.232562 | hard=1.772412 | soft=4.205995 | top1=0.4844 | top5=0.9453
#   Batch 0130/390 | total=2.848423 | hard=1.300632 | soft=3.880283 | top1=0.5469 | top5=0.9609
#   Batch 0140/390 | total=2.970624 | hard=1.330011 | soft=4.064365 | top1=0.6094 | top5=0.9141
#   Batch 0150/390 | total=2.820119 | hard=1.474432 | soft=3.717244 | top1=0.5703 | top5=0.9375
#   Batch 0160/390 | total=3.119999 | hard=1.378987 | soft=4.280674 | top1=0.5234 | top5=0.9609
#   Batch 0170/390 | total=3.288091 | hard=1.562223 | soft=4.438670 | top1=0.5781 | top5=0.9219
#   Batch 0180/390 | total=2.944591 | hard=1.426427 | soft=3.956701 | top1=0.5938 | top5=0.9062
#   Batch 0190/390 | total=3.178669 | hard=1.366565 | soft=4.386739 | top1=0.6250 | top5=0.9297
#   Batch 0200/390 | total=3.005172 | hard=1.455877 | soft=4.038036 | top1=0.5703 | top5=0.9297
#   Batch 0210/390 | total=2.695456 | hard=1.215064 | soft=3.682384 | top1=0.5859 | top5=0.9531
#   Batch 0220/390 | total=3.100758 | hard=1.449644 | soft=4.201500 | top1=0.5781 | top5=0.9531
#   Batch 0230/390 | total=2.883757 | hard=1.307267 | soft=3.934750 | top1=0.5547 | top5=0.9531
#   Batch 0240/390 | total=2.572931 | hard=1.122071 | soft=3.540171 | top1=0.6641 | top5=0.9219
#   Batch 0250/390 | total=2.758619 | hard=1.197107 | soft=3.799627 | top1=0.6641 | top5=0.9297
#   Batch 0260/390 | total=3.067318 | hard=1.630844 | soft=4.024968 | top1=0.5391 | top5=0.8984
#   Batch 0270/390 | total=3.033658 | hard=1.685996 | soft=3.932099 | top1=0.5312 | top5=0.8672
#   Batch 0280/390 | total=3.123211 | hard=1.466065 | soft=4.227975 | top1=0.5625 | top5=0.9141
#   Batch 0290/390 | total=3.152488 | hard=1.536233 | soft=4.229990 | top1=0.5391 | top5=0.9219
#   Batch 0300/390 | total=3.348571 | hard=1.669261 | soft=4.468112 | top1=0.4688 | top5=0.9219
#   Batch 0310/390 | total=3.448253 | hard=1.619856 | soft=4.667185 | top1=0.5391 | top5=0.9219
#   Batch 0320/390 | total=2.715017 | hard=1.228250 | soft=3.706195 | top1=0.5781 | top5=0.9375
#   Batch 0330/390 | total=3.078996 | hard=1.501689 | soft=4.130534 | top1=0.5234 | top5=0.9062
#   Batch 0340/390 | total=2.508767 | hard=1.117026 | soft=3.436594 | top1=0.6172 | top5=0.9688
#   Batch 0350/390 | total=2.899147 | hard=1.428655 | soft=3.879474 | top1=0.6094 | top5=0.9297
#   Batch 0360/390 | total=2.846343 | hard=1.355913 | soft=3.839963 | top1=0.5312 | top5=0.9297
#   Batch 0370/390 | total=2.729862 | hard=1.266684 | soft=3.705314 | top1=0.6094 | top5=0.9453
#   Batch 0380/390 | total=2.928236 | hard=1.492936 | soft=3.885103 | top1=0.5312 | top5=0.9531
#   Batch 0390/390 | total=2.634777 | hard=1.513259 | soft=3.382455 | top1=0.5938 | top5=0.9219
#   Val: top1=57.96% | top5=94.17% | CE_loss=1.393266
#   [checkpoint] New best val_top1=0.579627 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 12/50
#   Batch 0001/390 | total=2.898231 | hard=1.341416 | soft=3.936107 | top1=0.5938 | top5=0.9531
#   Batch 0010/390 | total=2.967462 | hard=1.420265 | soft=3.998927 | top1=0.6016 | top5=0.9453
#   Batch 0020/390 | total=3.382398 | hard=1.733977 | soft=4.481346 | top1=0.5547 | top5=0.9141
#   Batch 0030/390 | total=2.782089 | hard=1.333582 | soft=3.747761 | top1=0.5703 | top5=0.9375
#   Batch 0040/390 | total=2.715187 | hard=1.252022 | soft=3.690630 | top1=0.5859 | top5=0.9141
#   Batch 0050/390 | total=3.108776 | hard=1.469560 | soft=4.201586 | top1=0.5547 | top5=0.9688
#   Batch 0060/390 | total=2.672869 | hard=1.313815 | soft=3.578904 | top1=0.5859 | top5=0.9141
#   Batch 0070/390 | total=3.235240 | hard=1.615620 | soft=4.314986 | top1=0.5469 | top5=0.9609
#   Batch 0080/390 | total=3.104684 | hard=1.481221 | soft=4.186993 | top1=0.5078 | top5=0.9219
#   Batch 0090/390 | total=2.620320 | hard=1.164694 | soft=3.590737 | top1=0.6250 | top5=0.9531
#   Batch 0100/390 | total=3.102755 | hard=1.525729 | soft=4.154106 | top1=0.5391 | top5=0.9062
#   Batch 0110/390 | total=3.111979 | hard=1.316628 | soft=4.308880 | top1=0.5859 | top5=0.9219
#   Batch 0120/390 | total=2.993610 | hard=1.511801 | soft=3.981482 | top1=0.6094 | top5=0.9453
#   Batch 0130/390 | total=2.621770 | hard=1.321316 | soft=3.488739 | top1=0.5703 | top5=0.9609
#   Batch 0140/390 | total=2.925465 | hard=1.434489 | soft=3.919449 | top1=0.5156 | top5=0.9453
#   Batch 0150/390 | total=2.664338 | hard=1.297216 | soft=3.575753 | top1=0.6016 | top5=0.9531
#   Batch 0160/390 | total=3.049897 | hard=1.483915 | soft=4.093884 | top1=0.5625 | top5=0.9297
#   Batch 0170/390 | total=2.955400 | hard=1.299949 | soft=4.059033 | top1=0.6641 | top5=0.9375
#   Batch 0180/390 | total=3.103369 | hard=1.624154 | soft=4.089511 | top1=0.5703 | top5=0.9609
#   Batch 0190/390 | total=2.623682 | hard=1.274464 | soft=3.523160 | top1=0.6562 | top5=0.9141
#   Batch 0200/390 | total=2.307080 | hard=0.996587 | soft=3.180743 | top1=0.6484 | top5=0.9609
#   Batch 0210/390 | total=2.708616 | hard=1.302557 | soft=3.645988 | top1=0.5859 | top5=0.9766
#   Batch 0220/390 | total=3.003875 | hard=1.451227 | soft=4.038974 | top1=0.5938 | top5=0.9375
#   Batch 0230/390 | total=3.320675 | hard=1.746466 | soft=4.370148 | top1=0.4766 | top5=0.8984
#   Batch 0240/390 | total=3.107729 | hard=1.436130 | soft=4.222128 | top1=0.6016 | top5=0.9453
#   Batch 0250/390 | total=2.576666 | hard=1.346260 | soft=3.396937 | top1=0.6016 | top5=0.9375
#   Batch 0260/390 | total=2.785736 | hard=1.337381 | soft=3.751306 | top1=0.6250 | top5=0.9844
#   Batch 0270/390 | total=3.318871 | hard=1.803200 | soft=4.329319 | top1=0.4844 | top5=0.9062
#   Batch 0280/390 | total=3.231481 | hard=1.621549 | soft=4.304768 | top1=0.5625 | top5=0.9297
#   Batch 0290/390 | total=2.878011 | hard=1.611243 | soft=3.722522 | top1=0.5234 | top5=0.9297
#   Batch 0300/390 | total=2.701499 | hard=1.248485 | soft=3.670175 | top1=0.6094 | top5=0.9531
#   Batch 0310/390 | total=3.093126 | hard=1.584982 | soft=4.098555 | top1=0.5703 | top5=0.9062
#   Batch 0320/390 | total=3.164106 | hard=1.778680 | soft=4.087723 | top1=0.4531 | top5=0.9219
#   Batch 0330/390 | total=2.858017 | hard=1.499533 | soft=3.763674 | top1=0.5391 | top5=0.9609
#   Batch 0340/390 | total=2.917116 | hard=1.414739 | soft=3.918701 | top1=0.5625 | top5=0.9531
#   Batch 0350/390 | total=2.673680 | hard=1.235468 | soft=3.632488 | top1=0.6172 | top5=0.9453
#   Batch 0360/390 | total=3.266125 | hard=1.468949 | soft=4.464242 | top1=0.5859 | top5=0.9531
#   Batch 0370/390 | total=2.972781 | hard=1.442135 | soft=3.993211 | top1=0.6016 | top5=0.9219
#   Batch 0380/390 | total=3.516890 | hard=1.635825 | soft=4.770933 | top1=0.5391 | top5=0.9297
#   Batch 0390/390 | total=2.958008 | hard=1.212176 | soft=4.121896 | top1=0.6172 | top5=0.9609
#   Val: top1=59.52% | top5=94.37% | CE_loss=1.354837
#   [checkpoint] New best val_top1=0.595152 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 13/50
#   Batch 0001/390 | total=2.870023 | hard=1.433580 | soft=3.827652 | top1=0.5703 | top5=0.9375
#   Batch 0010/390 | total=2.864476 | hard=1.302553 | soft=3.905758 | top1=0.5234 | top5=0.9297
#   Batch 0020/390 | total=3.052686 | hard=1.422067 | soft=4.139766 | top1=0.6250 | top5=0.9219
#   Batch 0030/390 | total=2.815490 | hard=1.304350 | soft=3.822916 | top1=0.6328 | top5=0.9297
#   Batch 0040/390 | total=2.966694 | hard=1.263921 | soft=4.101876 | top1=0.6406 | top5=0.9297
#   Batch 0050/390 | total=2.910223 | hard=1.451825 | soft=3.882488 | top1=0.5859 | top5=0.9531
#   Batch 0060/390 | total=3.154655 | hard=1.520376 | soft=4.244173 | top1=0.5859 | top5=0.9219
# ...
#   Batch 0370/390 | total=1.878096 | hard=1.104962 | soft=2.393519 | top1=0.7266 | top5=0.9453
#   Batch 0380/390 | total=1.530507 | hard=0.715411 | soft=2.073904 | top1=0.7734 | top5=0.9766
#   Batch 0390/390 | total=2.160271 | hard=1.147013 | soft=2.835776 | top1=0.6797 | top5=0.9609
#   Val: top1=71.99% | top5=97.44% | CE_loss=1.004424
#   [checkpoint] New best val_top1=0.719852 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Epoch 47/50
#   Batch 0001/390 | total=1.747434 | hard=0.971539 | soft=2.264697 | top1=0.7500 | top5=0.9766
#   Batch 0010/390 | total=1.581138 | hard=0.867587 | soft=2.056838 | top1=0.7422 | top5=0.9766
#   Batch 0020/390 | total=1.529931 | hard=0.775772 | soft=2.032703 | top1=0.7734 | top5=0.9766
#   Batch 0030/390 | total=1.156689 | hard=0.428957 | soft=1.641844 | top1=0.8438 | top5=0.9922
#   Batch 0040/390 | total=1.477392 | hard=0.800709 | soft=1.928513 | top1=0.7422 | top5=0.9766
#   Batch 0050/390 | total=1.843924 | hard=0.861165 | soft=2.499096 | top1=0.7500 | top5=0.9766
#   Batch 0060/390 | total=1.276293 | hard=0.583398 | soft=1.738224 | top1=0.8281 | top5=0.9922
#   Batch 0070/390 | total=1.739915 | hard=0.859388 | soft=2.326932 | top1=0.7266 | top5=0.9766
#   Batch 0080/390 | total=1.774785 | hard=1.008599 | soft=2.285576 | top1=0.6953 | top5=0.9766
#   Batch 0090/390 | total=1.829613 | hard=1.025903 | soft=2.365420 | top1=0.6719 | top5=0.9531
#   Batch 0100/390 | total=1.859253 | hard=1.045779 | soft=2.401570 | top1=0.6875 | top5=0.9844
#   Batch 0110/390 | total=1.816366 | hard=1.128802 | soft=2.274742 | top1=0.6797 | top5=0.9688
#   Batch 0120/390 | total=1.985393 | hard=1.132301 | soft=2.554120 | top1=0.7109 | top5=0.9297
#   Batch 0130/390 | total=1.633237 | hard=0.889780 | soft=2.128875 | top1=0.7031 | top5=0.9844
#   Batch 0140/390 | total=1.164618 | hard=0.531645 | soft=1.586601 | top1=0.8203 | top5=0.9766
#   Batch 0150/390 | total=1.644451 | hard=0.892936 | soft=2.145462 | top1=0.7656 | top5=0.9844
#   Batch 0160/390 | total=2.158615 | hard=1.052140 | soft=2.896265 | top1=0.7031 | top5=0.9766
#   Batch 0170/390 | total=1.813607 | hard=1.060272 | soft=2.315829 | top1=0.7344 | top5=0.9688
#   Batch 0180/390 | total=1.619310 | hard=0.843823 | soft=2.136301 | top1=0.7734 | top5=0.9922
#   Batch 0190/390 | total=1.454465 | hard=0.598613 | soft=2.025033 | top1=0.8047 | top5=0.9688
#   Batch 0200/390 | total=1.376094 | hard=0.699911 | soft=1.826882 | top1=0.8203 | top5=0.9922
#   Batch 0210/390 | total=1.776972 | hard=0.942026 | soft=2.333603 | top1=0.7422 | top5=0.9609
#   Batch 0220/390 | total=1.602135 | hard=0.797069 | soft=2.138846 | top1=0.7344 | top5=0.9844
#   Batch 0230/390 | total=1.895070 | hard=1.067256 | soft=2.446946 | top1=0.7031 | top5=0.9531
#   Batch 0240/390 | total=1.568850 | hard=0.704187 | soft=2.145292 | top1=0.7656 | top5=0.9844
#   Batch 0250/390 | total=1.444029 | hard=0.718988 | soft=1.927389 | top1=0.7656 | top5=0.9922
#   Batch 0260/390 | total=1.737496 | hard=0.976308 | soft=2.244954 | top1=0.6797 | top5=1.0000
#   Batch 0270/390 | total=1.900559 | hard=1.000695 | soft=2.500468 | top1=0.6719 | top5=0.9922
#   Batch 0280/390 | total=2.050543 | hard=1.092601 | soft=2.689170 | top1=0.6484 | top5=0.9922
#   Batch 0290/390 | total=1.590808 | hard=0.771773 | soft=2.136831 | top1=0.7812 | top5=0.9922
#   Batch 0300/390 | total=1.699198 | hard=0.964644 | soft=2.188900 | top1=0.7266 | top5=0.9844
#   Batch 0310/390 | total=1.678721 | hard=0.866304 | soft=2.220333 | top1=0.7656 | top5=0.9609
#   Batch 0320/390 | total=1.923711 | hard=1.184361 | soft=2.416611 | top1=0.7031 | top5=0.9609
#   Batch 0330/390 | total=1.785282 | hard=1.041959 | soft=2.280831 | top1=0.6875 | top5=0.9609
#   Batch 0340/390 | total=1.869108 | hard=1.080096 | soft=2.395115 | top1=0.7266 | top5=0.9609
#   Batch 0350/390 | total=1.596141 | hard=0.666349 | soft=2.216002 | top1=0.7656 | top5=0.9766
#   Batch 0360/390 | total=2.081527 | hard=1.170231 | soft=2.689056 | top1=0.6875 | top5=0.9609
#   Batch 0370/390 | total=1.564382 | hard=0.814150 | soft=2.064537 | top1=0.7344 | top5=0.9844
#   Batch 0380/390 | total=1.714997 | hard=0.988153 | soft=2.199560 | top1=0.7109 | top5=0.9688
#   Batch 0390/390 | total=1.675094 | hard=0.713856 | soft=2.315919 | top1=0.8047 | top5=0.9766
#   Val: top1=71.90% | top5=97.29% | CE_loss=1.022599
#   Batch 0150/390 | total=1.546556 | hard=0.862273 | soft=2.002745 | top1=0.7578 | top5=0.9766
#   Batch 0160/390 | total=1.278938 | hard=0.727418 | soft=1.646617 | top1=0.7422 | top5=0.9922
#   Batch 0170/390 | total=1.767153 | hard=0.990904 | soft=2.284652 | top1=0.7188 | top5=0.9766
#   Batch 0180/390 | total=1.342000 | hard=0.714207 | soft=1.760528 | top1=0.7734 | top5=0.9922
#   Batch 0190/390 | total=1.511314 | hard=0.603310 | soft=2.116650 | top1=0.8203 | top5=0.9922
#   Batch 0200/390 | total=1.663252 | hard=0.885388 | soft=2.181828 | top1=0.7188 | top5=0.9766
#   Batch 0210/390 | total=1.609770 | hard=0.876682 | soft=2.098495 | top1=0.7422 | top5=0.9766
#   Batch 0220/390 | total=1.739478 | hard=0.952102 | soft=2.264395 | top1=0.7344 | top5=0.9766
#   Batch 0230/390 | total=1.630303 | hard=0.809413 | soft=2.177563 | top1=0.7344 | top5=0.9922
#   Batch 0240/390 | total=1.852594 | hard=1.064371 | soft=2.378076 | top1=0.7031 | top5=0.9688
#   Batch 0250/390 | total=1.771401 | hard=1.018848 | soft=2.273103 | top1=0.7344 | top5=0.9922
#   Batch 0260/390 | total=1.501518 | hard=0.858139 | soft=1.930437 | top1=0.7422 | top5=0.9531
#   Batch 0270/390 | total=1.807234 | hard=1.127099 | soft=2.260657 | top1=0.6562 | top5=0.9922
#   Batch 0280/390 | total=1.578919 | hard=0.740194 | soft=2.138069 | top1=0.7734 | top5=1.0000
#   Batch 0290/390 | total=1.692571 | hard=0.904723 | soft=2.217803 | top1=0.7188 | top5=0.9766
#   Batch 0300/390 | total=1.668820 | hard=0.855947 | soft=2.210736 | top1=0.7109 | top5=1.0000
#   Batch 0310/390 | total=1.788216 | hard=1.015311 | soft=2.303486 | top1=0.7109 | top5=0.9922
#   Batch 0320/390 | total=1.540767 | hard=0.745530 | soft=2.070925 | top1=0.7812 | top5=0.9844
#   Batch 0330/390 | total=1.902984 | hard=1.005490 | soft=2.501313 | top1=0.7109 | top5=0.9766
#   Batch 0340/390 | total=1.449538 | hard=0.821695 | soft=1.868101 | top1=0.7812 | top5=0.9766
#   Batch 0350/390 | total=1.657179 | hard=0.812468 | soft=2.220320 | top1=0.7344 | top5=0.9922
#   Batch 0360/390 | total=1.765197 | hard=0.984644 | soft=2.285566 | top1=0.7031 | top5=0.9609
#   Batch 0370/390 | total=2.078078 | hard=1.134353 | soft=2.707228 | top1=0.6328 | top5=0.9844
#   Batch 0380/390 | total=1.649820 | hard=0.752998 | soft=2.247702 | top1=0.7734 | top5=0.9766
#   Batch 0390/390 | total=1.694350 | hard=0.699863 | soft=2.357341 | top1=0.7422 | top5=0.9844
#   Val: top1=71.47% | top5=97.31% | CE_loss=1.012811
# Epoch 50/50
#   Batch 0001/390 | total=1.496297 | hard=0.788209 | soft=1.968355 | top1=0.7500 | top5=1.0000
#   Batch 0010/390 | total=1.714633 | hard=0.758944 | soft=2.351758 | top1=0.7578 | top5=0.9922
#   Batch 0020/390 | total=1.840336 | hard=1.062391 | soft=2.358966 | top1=0.6953 | top5=0.9766
#   Batch 0310/390 | total=1.698838 | hard=0.833250 | soft=2.275897 | top1=0.7422 | top5=0.9844
#   Batch 0320/390 | total=1.447982 | hard=0.667675 | soft=1.968186 | top1=0.8125 | top5=0.9844
#   Batch 0330/390 | total=1.584632 | hard=0.806882 | soft=2.103131 | top1=0.7891 | top5=0.9531
#   Batch 0340/390 | total=1.390729 | hard=0.670263 | soft=1.871039 | top1=0.7812 | top5=0.9766
#   Batch 0350/390 | total=1.672143 | hard=0.917168 | soft=2.175460 | top1=0.7109 | top5=0.9922
#   Batch 0360/390 | total=1.362939 | hard=0.572280 | soft=1.890045 | top1=0.8203 | top5=0.9922
#   Batch 0370/390 | total=1.368811 | hard=0.677388 | soft=1.829759 | top1=0.7969 | top5=0.9844
#   Batch 0380/390 | total=1.468388 | hard=0.813321 | soft=1.905099 | top1=0.7422 | top5=0.9766
#   Batch 0390/390 | total=1.776973 | hard=0.897412 | soft=2.363347 | top1=0.7031 | top5=0.9531
#   Val: top1=72.33% | top5=97.58% | CE_loss=0.967332
#   [checkpoint] New best val_top1=0.723257 — student saved to 'data/notebook_test/best_student_kd_pruned_cifar10.pt'
# Loaded best KD student weights from 'data/notebook_test/best_student_kd_pruned_cifar10.pt' for evaluation.

# %% [markdown]
# ## Evaluation: teacher vs pruned (no training) vs finetuned-only vs distilled student (CIFAR10 validation)

# %%
# --- Training loss summary ---
if "loss_history" in globals() and len(loss_history) > 0:
    print(f"Recorded {len(loss_history)} KD training batches")
    print(f"  First loss: {loss_history[0]:.6f}")
    print(f"  Last loss:  {loss_history[-1]:.6f}")
    if top1_history and not all(isinstance(v, float) and v != v for v in top1_history):
        valid_top1 = [v for v in top1_history if v == v]  # filter NaN
        if valid_top1:
            print(f"  Final train top1: {valid_top1[-1]*100:.2f}%")
    if top5_history and not all(isinstance(v, float) and v != v for v in top5_history):
        valid_top5 = [v for v in top5_history if v == v]
        if valid_top5:
            print(f"  Final train top5: {valid_top5[-1]*100:.2f}%")
else:
    print("No training loss history found in current kernel session.")

# --- Evaluate teacher + distilled student via the distiller ---
print("\n--- CIFAR10 Validation Results ---\n")

eval_results = distiller_cls.evaluate()
teacher_metrics = eval_results.get("teacher")
student_metrics = eval_results["student"]
val_kd_loss = eval_results["val_kd_loss"]
kd_batches = eval_results["kd_batches"]

def _fmt_metrics(m: dict) -> str:
    return (
        f"  top1_acc={m['top1_acc']*100:.2f}% | "
        f"top5_acc={m['top5_acc']*100:.2f}% | "
        f"CE_loss={m['avg_ce_loss']:.4f} | "
        f"fwd_ms/batch={m['avg_forward_ms_per_batch']:.2f} | "
        f"samples={m['samples']}"
    )

# --- Print results ---
if teacher_metrics is not None:
    print(f"Teacher (fine-tuned on CIFAR10):")
    print(_fmt_metrics(teacher_metrics))

if "baseline_pruned_metrics" in globals() and baseline_pruned_metrics is not None:
    print(f"\nStudent (pruned {PRUNE_SPARSITY*100:.0f}%, no training):")
    print(_fmt_metrics(baseline_pruned_metrics))

if "student_finetuned_metrics" in globals() and student_finetuned_metrics is not None:
    print(f"\nStudent (pruned {PRUNE_SPARSITY*100:.0f}%, finetuned {EPOCHS} epochs, no KD):")
    print(_fmt_metrics(student_finetuned_metrics))

print(f"\nDistilled student (pruned {PRUNE_SPARSITY*100:.0f}%, {EPOCHS} epochs, alpha={KD_ALPHA}, T={KD_TEMPERATURE}):")
print(_fmt_metrics(student_metrics))

print(f"\nValidation KD loss (teacher vs distilled student, T={KD_TEMPERATURE}): "
      f"{val_kd_loss:.6f} over {kd_batches} batches")

# --- Summary table ---
print("\n--- Summary ---")
print(f"{'Model':<50} {'Top-1 Acc':>10} {'Top-5 Acc':>10} {'CE Loss':>10}")
print(f"{'─'*50} {'─'*10} {'─'*10} {'─'*10}")
if teacher_metrics is not None:
    print(f"{'Teacher (fine-tuned)':<50} {teacher_metrics['top1_acc']*100:>9.2f}% {teacher_metrics['top5_acc']*100:>9.2f}% {teacher_metrics['avg_ce_loss']:>10.4f}")
if "baseline_pruned_metrics" in globals() and baseline_pruned_metrics is not None:
    label = f"Student (pruned {PRUNE_SPARSITY*100:.0f}%, no training)"
    print(f"{label:<50} {baseline_pruned_metrics['top1_acc']*100:>9.2f}% {baseline_pruned_metrics['top5_acc']*100:>9.2f}% {baseline_pruned_metrics['avg_ce_loss']:>10.4f}")
if "student_finetuned_metrics" in globals() and student_finetuned_metrics is not None:
    label = f"Student (pruned {PRUNE_SPARSITY*100:.0f}%, finetuned, no KD)"
    print(f"{label:<50} {student_finetuned_metrics['top1_acc']*100:>9.2f}% {student_finetuned_metrics['top5_acc']*100:>9.2f}% {student_finetuned_metrics['avg_ce_loss']:>10.4f}")
label = f"Distilled student (pruned {PRUNE_SPARSITY*100:.0f}%, KD)"
print(f"{label:<50} {student_metrics['top1_acc']*100:>9.2f}% {student_metrics['top5_acc']*100:>9.2f}% {student_metrics['avg_ce_loss']:>10.4f}")
# Out:
# Recorded 19500 KD training batches
#   First loss: 6.382877
#   Last loss:  1.776973
#   Final train top1: 70.31%
#   Final train top5: 95.31%
#
# --- CIFAR10 Validation Results ---
#
# Teacher (fine-tuned on CIFAR10):
#   top1_acc=91.25% | top5_acc=99.69% | CE_loss=0.2784 | fwd_ms/batch=63.08 | samples=9984
#
# Student (pruned 50%, no training):
#   top1_acc=10.69% | top5_acc=49.80% | CE_loss=2.3750 | fwd_ms/batch=104.29 | samples=9984
#
# Student (pruned 50%, finetuned 50 epochs, no KD):
#   top1_acc=68.65% | top5_acc=96.85% | CE_loss=0.9070 | fwd_ms/batch=37.94 | samples=9984
#
# Distilled student (pruned 50%, 50 epochs, alpha=0.6, T=8.0):
#   top1_acc=72.33% | top5_acc=97.58% | CE_loss=0.9673 | fwd_ms/batch=51.46 | samples=9984
#
# Validation KD loss (teacher vs distilled student, T=8.0): 2.180726 over 78 batches
#
# --- Summary ---
# Model                                               Top-1 Acc  Top-5 Acc    CE Loss
# ────────────────────────────────────────────────── ────────── ────────── ──────────
# Teacher (fine-tuned)                                   91.25%     99.69%     0.2784
# Student (pruned 50%, no training)                      10.69%     49.80%     2.3750
# Student (pruned 50%, finetuned, no KD)                 68.65%     96.85%     0.9070
# Distilled student (pruned 50%, KD)                     72.33%     97.58%     0.9673

# %%
import matplotlib.pyplot as plt
import math

def _epoch_avg(hist: list[float], n_epochs: int) -> list[float]:
    """Average a per-batch history into per-epoch values."""
    if not hist or n_epochs == 0:
        return []
    batches_per_epoch = len(hist) // n_epochs
    if batches_per_epoch == 0:
        return []
    return [
        sum(hist[e * batches_per_epoch : (e + 1) * batches_per_epoch]) / batches_per_epoch
        for e in range(n_epochs)
    ]

def _epoch_avg_no_nan(hist: list[float], n_epochs: int) -> list[float]:
    """Average a per-batch history into per-epoch values, skipping NaN entries."""
    if not hist or n_epochs == 0:
        return []
    batches_per_epoch = len(hist) // n_epochs
    if batches_per_epoch == 0:
        return []
    result = []
    for e in range(n_epochs):
        chunk = [v for v in hist[e * batches_per_epoch : (e + 1) * batches_per_epoch]
                 if not math.isnan(v)]
        result.append(sum(chunk) / len(chunk) if chunk else float("nan"))
    return result

epochs_axis = list(range(1, EPOCHS + 1))

# Per-batch train histories averaged to per-epoch
ft_loss_epoch  = _epoch_avg(ft_loss_history, EPOCHS)
kd_loss_epoch  = _epoch_avg(loss_history, EPOCHS)
ft_top1_epoch  = _epoch_avg_no_nan(ft_top1_history, EPOCHS)
kd_top1_epoch  = _epoch_avg_no_nan(top1_history, EPOCHS)

# Validation histories are already per-epoch (one value per epoch)
ft_val_loss_epoch  = ft_val_loss_history
ft_val_top1_epoch  = ft_val_top1_history
kd_val_loss_epoch  = val_loss_history
kd_val_top1_epoch  = val_top1_history

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(
    f"Training & Validation Curves per Epoch: Finetuned (no KD) vs Distilled Pruned Student "
    f"({PRUNE_SPARSITY*100:.0f}% sparsity)",
    fontsize=12,
)

# --- Loss curve ---
ax = axes[0]
ax.plot(epochs_axis, ft_loss_epoch,     label="Finetuned – train", marker="o", markersize=3, linewidth=1.2)
ax.plot(epochs_axis, ft_val_loss_epoch, label="Finetuned – val",   marker="s", markersize=3, linewidth=1.2, linestyle="--")
ax.plot(epochs_axis, kd_loss_epoch,     label="Distilled – train", marker="o", markersize=3, linewidth=1.2)
ax.plot(epochs_axis, kd_val_loss_epoch, label="Distilled – val",   marker="s", markersize=3, linewidth=1.2, linestyle="--")
ax.set_xlabel("Epoch")
ax.set_ylabel("Avg Loss")
ax.set_title("Training & Validation Loss (epoch avg)")
ax.legend()
ax.grid(True, alpha=0.3)

# --- Top-1 accuracy curve ---
ax = axes[1]
ax.plot(epochs_axis, ft_top1_epoch,     label="Finetuned – train", marker="o", markersize=3, linewidth=1.2)
ax.plot(epochs_axis, ft_val_top1_epoch, label="Finetuned – val",   marker="s", markersize=3, linewidth=1.2, linestyle="--")
ax.plot(epochs_axis, kd_top1_epoch,     label="Distilled – train", marker="o", markersize=3, linewidth=1.2)
ax.plot(epochs_axis, kd_val_top1_epoch, label="Distilled – val",   marker="s", markersize=3, linewidth=1.2, linestyle="--")
ax.set_xlabel("Epoch")
ax.set_ylabel("Avg Top-1 Accuracy")
ax.set_title("Training & Validation Top-1 Accuracy (epoch avg)")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"{y*100:.0f}%"))
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
